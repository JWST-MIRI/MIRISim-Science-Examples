# %% [markdown]
# #  SN1987A:  MIRISim (MRS IFU)
#
# #### This notebook replicates the MIRI MRS IFU spectroscopy part of the SN 1987A: The Formation and Evolution of Dust in a Supernova Explosion JWST GTO programme (#1232).
#
# Details of generating ETC and APT files in this example science program can be found on the JDoX webpages: https://jwst-docs.stsci.edu/mid-infrared-instrument/miri-example-science-programs/miri-mrs-and-nirspec-ifu-observations-of-sn1987a
#
# **Science Objective:**
# The main science goals of this project are to understand how massive stars age and explode, how their ejecta form dust and molecules, and how the blast wave from their violent explosion affects their surroundings. JWST MIRI imaging, and medium resolution spectroscopy (MRS) will provide key emission line diagnostics and dust feature and continuum measurements of SN 1987A. The central stellar ejecta of SN 1987A is surrounded by a ring of progenitor gas and dust that is being shocked by the blast wave of the explosion. A large quantity (0.4–0.7 solar masses; Matsuura et al. 2011) of dust in the stellar ejecta has an unknown composition, and these observations may provide the first constraints through imaging and spatially resolved spectroscopy.  The **MRS IFU** spectroscopy will measure key shocked line diagnostics that will further constrain the shock physics as well as the elemental abundances in both the ring and the stellar ejecta.
#
# **In this notebook**, we create a scene with a cold blackbody ~ 20K replicating the inner ejecta of SN 1987A and a ring of warm (~ 100K) silicate dust and atomic emission lines surrounding the ejecta that all fit within the MRS field of view, and run through a MIRISim simulation showing the products created at each stage.
#
# **NOTE** this notebook must be started within  the correct anaconda environment in which you have MIRISim installed. This is a prerequisite for using MIRISim, and installation instructions can be found [here](http://miri.ster.kuleuven.be/bin/view/Public/MiricleInstallation).
#
# When launching the notebook, make sure in the right Anaconda environment. i.e. type
#
#
# <code> source activate miricle </code>
#
# in the terminal before starting the notebook.
#
# ### Steps in this notebook:
#
# 0. Import useful python packages
# 1. Create a Scene
# 2. Initialise the simulation parameters
# 3. Run the simulation
# 4. Examine some of the outputs.

# %% [markdown]
# ## Step 0 - Some general python housekeeping
# ### Import useful python packages

# %%
# Import usefull python packages
import numpy as np
import glob                 # glob is used to find the output directory
import os                   # for listing directory contents
from astropy.io import fits # for reading FITS file contents

# Import python packages used to display images inline in the notebook
import matplotlib.pyplot as plt    
from matplotlib import colors,cm
# %matplotlib inline       

######################################
# Now import MIRISim specific packages 

# import the configuration file parsers so they can be written to file
from mirisim.config_parser import SimConfig, SimulatorConfig, SceneConfig

# import scene component generators
from mirisim.skysim import Background, sed, Point, Galaxy, kinetics, ExternalSed
from mirisim.skysim import wrap_pysynphot as wS

from mirisim import MiriSimulation
# Out:
# WARNING: AstropyDeprecationWarning: astropy.extern.six will be removed in 4.0, use the six module directly if it is still needed [astropy.extern.six]

# %% [markdown]
# ### Define some common functions
#
# 1) <code>save_to_fits</code> - Used to save the generated scene to a fits file
#
# 2) <code>show_outputs</code> - Used in plotting outputs from MIRISim
#
# 3) <code>row_based_idx</code> - Used to fill matplotlib subplots by column, not row
#
# 4) <code>show_skycubes_spec</code> - Used to plot the spectrum in datacubes generated by MIRISim

# %%
def save_to_fits(scene, light_path, filename='MIRISim_scene.fits', SpatialSampling=0.1, WavelengthRange=None, 
                 WavelengthSampling=0.1):
    """
    Function to save the MIRISim scene to a fits file.
    
    :param filename: Name of file to save - default is "MIRISim_scene.fits"
    :type filename: string       
    
    :param SpatialSampling: Spatial sampling (in arcsec) - default is 0.1 arcseconds
    :type SpatialSampling: float
    
    :param WavelengthRange: Wavelength range to process (in microns) - default is [5, 28] microns
    :type WavelengthRange: array
    
    :param WavelengthSampling: Channel width (in microns) - default is 0.1 arcseconds
    :type WavelengthSampling: float
    
    :rtype: None
    :raises Exception: when light_path parameter not set to MRS or IMA
    """
    
    # Avoids array being extended inside function for mutliple calls. Python gotcha
    if WavelengthRange is None:
        WavelengthRange = [5, 28]
        
    if light_path == 'IMA':
        # IMA Field of view [xmin,xmax],[ymin,ymax] [arcsec]
        FOV = np.array([[-57., 57.],[-57., 57.]])   
    elif light_path == "MRS":
        # MRS Field of view [xmin,xmax],[ymin,ymax] [arcsec]
        FOV = np.array([[-4., 4.],[-4., 4.]])       
    else:
        raise Exception('Acceptable inputs for parameter light_path are [IMA] and [MRS]')
    
    # overwrite = True enables overwriting of any previous version of the fits file
    # with the same name as that given in the writecube command
    scene.writecube(cubefits = filename,
                    FOV = FOV, time = 0.0,
                    spatsampling = SpatialSampling,
                    wrange = WavelengthRange,
                    wsampling = WavelengthSampling,
                    overwrite = True)

# %%
def show_outputs(MIRISim_outputdir,output_type):
    """
    Plot the specified channel of the MIRISim outputs
    :param MIRISim_outputdir:  
        name of the date-labelled dir. holding the MIRISIM outputs
    :param output_type: 
        type of output to process 
        (e.g. illum_models, det_images or skycubes)
    """
    
    infits = glob.glob('{}/{}/*.fits'.format(MIRISim_outputdir,output_type))[0]
    
    hdulist = fits.open(infits)
    
    if output_type.lower() == 'skycubes': 
        hdu_index = 0
        datashape = hdulist[hdu_index].data.shape
        central_chan = datashape[0]//2
        
        plt.imshow(hdulist[hdu_index].data[central_chan,:,:],
           origin = 'lower', interpolation = 'nearest',cmap = cm.viridis, aspect='equal')
        plt.title('channel {} of {}'.format(central_chan,infits.split('/')[-1]))
        plt.xlabel(hdulist[hdu_index].header['ctype1'])
        plt.ylabel(hdulist[hdu_index].header['ctype2'])
    else:
        hdu_index = 1
        if len(hdulist[hdu_index].data.shape) > 2:
            integ,frames,nx,ny = hdulist[hdu_index].data.shape
            image = hdulist[hdu_index].data[integ-1,frames-1,:,:]
        else:
            image = hdulist[hdu_index].data
            
        
        plt.imshow(image, origin = 'lower',cmap = cm.viridis,interpolation='nearest', aspect='equal')
        plt.title('{}'.format(infits.split('/')[-1]))
        plt.xlabel('Along Slice Direction')
        plt.ylabel('Wavelength Direction')

    plt.colorbar()

# %%
def row_based_idx(num_rows, num_cols, idx):
    """
    Function to fill matplotlib subplots by column, not row
    """
    return np.arange(1, num_rows*num_cols + 1).reshape((num_rows, num_cols)).transpose().flatten()[idx-1]

# %%
def show_skycubes_spec(directory_list):
    """
    Plots the average MIRISim spectra for each FOV from the 12 skycubes generated from 
    the Short, Medium and Long dispersers
    :param directory_list:  
        List contaning the three output directories for the MRS simulation results
    """    
    
    # Define subplot grid for the MRS skycubes
    num_cols = 3 
    num_rows = 4             

    maxfigs = 12
    fig = plt.figure(figsize=(10,3*num_rows))
    i=0

    for num, outputdir in enumerate(directory_list):
        outputDirContents = os.listdir(outputdir)

        directories = [name for name in outputDirContents if os.path.isdir(os.path.join(outputdir,name))]

        #print('\nFor the {} the output directory is: {} '.format(sim_filenames[num], outputdir))
        #print('This directory contains four skycubes which cover the wavelength ranges:')

        filenames_skycube = glob.glob('{}/{}/*.fits'.format(outputdir,'skycubes')) # Get skycube file

        for skycube_file in filenames_skycube:

            hdu = fits.open(skycube_file)        # Open file 
            data_cube = hdu[0].data              # Get data 
            #datashape = hdu[0].data.shape       # Get data shape - Z, X, Y  

            # Get the wavelength data 
            wav =  hdu[1].data

            # Find the max and min wavelelgths for the output cube
            vmin = wav[0]
            vmax = wav[-1]       
            #print(np.round(vmin,2), np.round(vmax,2))

            # Get the flux data from an average of the cube
            spectrum = data_cube.mean(axis=(1, 2))  

            # Plot the spectrum - Each colum = short, medium, long
            plt.subplot(num_rows, num_cols, row_based_idx(num_rows, num_cols,i+1))
            plt.plot(wav, spectrum)                                       
            #plt.xticks([])  # help clean up the plot
            plt.yticks([])   # help clean up the plot 
            i+=1    

    fig.add_subplot(111, frame_on=False)

    plt.tick_params(labelcolor="none", bottom=False, left=False)
    plt.xlabel("Wavelength (microns)", fontsize=14)
    plt.ylabel("Flux (data units)", fontsize=14)

    fig.suptitle('    Short                           Medium                           Long', y=1.02, fontsize=18)

    fig.tight_layout()

    plt.show()
    plt.close()

# %% [markdown]
# ### Set flags for saving the MIRISim scene to a fits file - default is False
# We select false as the default as 1) a fits file of the scene is not necessary to run mirisim; 2) this step can take a long time to run; 3) once a scene has been saved as a fits file one this step is not necessary.

# %%
save_scene_as_fits = False

# %% [markdown]
# ## Step 1 - Create a Scene - this represents your science observation
#
# Each scene should include at minimum: 1) A background level; 2) A science source
#
# The scene created below consists of a cold ~ 20K blackbody replicating the inner ejecta of SN1987A and a ring of warm silicate dust surrounding the ejecta that all of which fit within the MRS field of view. The first point source has a 20 K blackbody SED, the ring has a SED imported from Spitzer IRS observations.

# %% [markdown]
# #### Create a low level background for the scene

# %%
bg = Background(level='low',gradient=9., pa=45.)
# Out:
# 2020-02-24 17:35:02,164 - INFO - Initializing Background

# %% [markdown]
# #### Create the First Point Source - replicating the cold (~20 K) dust in the inner ejecta - Flux values and tempratures from Matsuura et al. 2011

# %%
# Initialise a single point source at the central position of the MIRI MRS
"""
MIRI MRS FOV     = 3.7 × 3.7  arcseconds  in ALL four channels 
Max MIRI MRS FOV = 7.2 × 7.9  arcseconds  
"""
point1 = Point(Cen = (0.0,0.0))

# Set properties of the SED for point 1
Blackbody = sed.BBSed(Temp = 26., wref = 20., flux = 45.4 * 1000)  # Temp = K, wref = microns, flux = micro Jy 

# Add the SED to the point source
point1.set_SED(Blackbody)

# Add ejecta (point1) to the compound target list called 'sn1987A_components' for creating a scene
sn1987A_components = point1

# For writing to scene.ini file
targetlist = [point1]
# Out:
# 2020-02-24 17:35:02,172 - INFO - Initializing Point

# %% [markdown]
# ### Create the ring surrounding the ejecta
#
# #### 1) First import the SED from an external file

# %%
# Get SEDs of the ring for SN1987A observed with Spitzer IRS. Data from Jones et al. 2017b 

# Use: sedfile =  ExternalSed('extsed.txt') # filepath, columns 'wavelength' [microns] and 'flux' [muJy]
ring_sed = ExternalSed(sedfile = 'SN1987A_ring_microJy.txt') 

# For zooming in on spectral ranges
l_min = 5 #micron
l_max = 28 #micron
sp_min = np.abs(ring_sed.Lam-l_min).argmin()
sp_max = np.abs(ring_sed.Lam-l_max).argmin()

# Plot the Spitzer spectrum of the SN1987A ring component for refrence
fig = plt.figure(figsize=(8, 6))
ax = plt.subplots()[1]  
ax.plot(ring_sed.Lam[sp_min:sp_max], ring_sed.fLam[sp_min:sp_max])   # TODO: Check units is this in Jy or W/m**2 
ax.set_xlabel("Wavelength (microns)")  
ax.set_ylabel("Flux (W/m**2)")  
ax.set_title("External SED of SN1987A ring")  
plt.close(fig)

# %% [markdown]
# #### 2) Then attach the SED to an object

# %%
# Set up the spatial distibution of the ring of SN1987A

# Create a ring of sources and add them to the scene
MRS_radius = 3.2/2.   # Radius of MRS (in arcsec)             
Nring = 16            # Number of ring components to put within the MRS 

# Create a circle of resolved objects to replicate the ring, add the SED to each object and add to the scene
for i in range(0,Nring):
      
    xp = np.cos(2*np.pi/Nring*i)*MRS_radius
    yp = np.sin(2*np.pi/Nring*i)*MRS_radius
    
    # Initlise a ring using the galaxy template of a non-pointsource 
    ring = Galaxy(Cen = (xp,yp),n=0.5,re=0.15,q=0.33,pa=360/Nring*i)  # n = sersic idx; re = eff. rad. [arcsec] ; q = axis ratio
 
    # Add the Spitzer IRS observtions of the ring from Jones et al 2017b to generate the SED of initialised ring
    ring.set_SED(ring_sed)

    sn1987A_components += ring    # For creating a scene
    targetlist.append(ring)       # For writing to scene.ini file
# Out:
# 2020-02-24 17:35:02,471 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,472 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,473 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,474 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,475 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,476 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,477 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,477 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,478 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,479 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,480 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,481 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,482 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,482 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,483 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,483 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,484 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,485 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,486 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,486 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,487 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,488 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,489 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,489 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,490 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,491 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,492 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,493 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,494 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,495 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,496 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,497 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,498 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,499 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,499 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,500 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,501 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,501 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,502 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,503 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,503 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,504 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,504 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,506 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,507 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,508 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,509 - INFO - Initializing Galaxy
# 2020-02-24 17:35:02,509 - INFO - Initializing Galaxy

# %% [markdown]
# ### From the components, create a scene
#
# To create a scene adding together the background and targets i.e the ejecta component and the ring components.

# %%
scene = bg +  sn1987A_components

# %% [markdown]
# ### Export the scene to an ini file and FITS file (optional)
#
# Export scene to an ini file (for future use), or a FITS file to be visualised. This stage is not necessary if runing mirisim in a notebook.
#
# Exporting to a FITS file requires specifing a number of aditional parametrs such as the Field of view, required spectral sampling, etc. They're described in more detail below. For large fields of view, and/or small spectral channels, which create large FITS files, writing to a FITS file can take a while (few minutes)

# %%
# Used to run MIRISim within notebook
scene_config = SceneConfig.makeScene(loglevel=0,
                                    background=bg,
                                    targets = targetlist)

# Export to ini file - not necessary if runing mirisim in notebook
os.system('rm -fr MRS_SN1987A_scene.ini')      # Remove previous version of .ini file
scene_config.write('MRS_SN1987A_scene.ini')

# %% [markdown]
# ##### OPTIONAL - Save the generted scene to a fits file - Note this step can take a long time depening on the chosen perameters

# %%
# Export to FITS file - Optional 
if save_scene_as_fits == True:
    save_to_fits(scene, light_path="MRS", filename='MIRISim_scene.fits')

# %% [markdown]
# ## Initialise the MRS Simulation Parameters
#
# This is where the parameters for the MRS simulation get set.  These should be set to match the desired MIRI observation setup.
#
# **Note** MIRISim must have perameters set for all light paths in <code>SimConfig.makeSim</code> this includes some perameters not relevent to the MRS simulation defined in this file. Those perameters not being used in this simulation are labelled with <code> NOT USED HERE </code> in the comments of each line **and should not be deleted**.
#
# ### SN1987A MRS obsevation set up:
#
# For SN 1987A we want to simulate a spectrum covering the full MRS 5-28 micron wavelength range.  To replicate this in MIRISim - **3 simulations are needed to obtain a full spectrum** using SHORT MEDIUM and LONG respectively using both the short and long wavelength arms (CH 1 & 2 and CH 3 & 4 respectively).
#
# 1. Dither = Extended source 4pt
# 2. Read out mode = <code>FAST</code> selected based on best practices.
#
# #### Desperser  -   Groups - Integrations
# - Short:  80 groups and 3 integrations
# - Medium: 80 groups and 3 integrations
# - Long:   80 groups and 3 integrations
#
# NB A <code>FAST</code> readout pattern selected due to high dynamic range in flux for the ring and the ejecta. This will prevent sauturaion.

# %% [markdown]
# ###  To get the full 5-28 micron spectral range this simulation uses all three despersers.
#
# #### In the MRS observation set up select appropriate values for the three despersers to loop the simulation over.
#
# The following setup assumes that the user is using the full MRS spectral range.
# Parameters to be adjusted based on your desired observation setup are the:
#
# * sim_filenames
# * mrs_exposure_values
# * mrs_integration_values
# * mrs_frame_values

# %%
# Generate a list of three config names for the simulations 
sim_config_list = ['sim_config_s', 'sim_config_m','sim_config_l']

# Set the file names of the three simulations
sim_filenames = ['MRS_short_SN1987A_simulation', 'MRS_medium_SN1987A_simulation', 'MRS_long_SN1987A_simulation']

# Configure the Optical path (MRS sub-band)  
config_path_list = ['MRS_1SHORT', 'MRS_1MEDIUM', 'MRS_1LONG']

# Which disperser to use (SHORT/MEDIUM/LONG) 
disperser_list = ['SHORT', 'MEDIUM', 'LONG']

# Number of MRS exposures 
mrs_exposure_values = [1,1,1]

# Number of MRS integrations
mrs_integration_values = [3,3,3]

# Number of groups (for MIRI, # Groups = # Frames)
mrs_frame_values = [80, 80, 80]

# %%
# Now to loop through the three desperser simulation setups 

# Generate combined list of the observation perameters for the three dispersers 
# based on the values imput in the previous cell.
observaton_setup = [
    sim_filenames, config_path_list, disperser_list,
    mrs_exposure_values, mrs_integration_values, mrs_frame_values]

print("SimConfig populated by:")

# Builds a list to contain the sim_obects built in the below loop
sim_objects = list()

# Generates the three simulation objects for the short medium and long and populates 
# the sim_objects list
# Use python zip function to index arrays to minimise potential errors by passing 
# arguments of unequal length 
for (sim_name_el, config_path_list_el, disperser_list_el, 
     mrs_exposer_value_el, mrs_integration_value_el, mrs_frame_values_el) in zip(*observaton_setup):
    
    print ("{} : {} : {} : {} : {} : {}".format(sim_name_el, config_path_list_el,
                                                     disperser_list_el, mrs_exposer_value_el, 
                                                     mrs_integration_value_el, mrs_frame_values_el))
    
    # Add a safety check to make sure each parameter contains values for all the disperser settings. 
    if (len(sim_config_list) != len(sim_filenames) != len(config_path_list) != len(disperser_list) 
        != len(mrs_exposure_values) != len(mrs_integration_values) != len(mrs_frame_values)):
        raise Exception("All three values are not set - Check imputs.")
    
    ############################################################################################
    # This sets up the simulation - adjust values spefific to your observation setup you wish to simulate 
    
    sim_objects.append(SimConfig.makeSim(
        name = sim_name_el,                   # Name given to simulation
        scene = 'MRS_SN1987A_scene.ini',      # Name of scene file to input

        rel_obsdate = 0.0,                    # Relative observation date (0 = launch, 1 = end of 5 yrs)
        POP = 'MRS',                          # Component on which to center (IMA or MRS)
        ConfigPath = config_path_list_el,     # Configure the Optical path (MRS sub-band)

        disperser = disperser_list_el,        # Which disperser to use (SHORT/MEDIUM/LONG)
        detector = 'BOTH',                    # Specify Channel (SW = channels 1,2, LW= channels 3,4, or BOTH)
        mrs_mode = 'FAST',                             # MRS read mode (default is Fast)
        mrs_exposures = mrs_exposer_value_el,          # Number of exposures
        mrs_integrations = mrs_integration_value_el,   # Number of integrations
        mrs_frames = mrs_frame_values_el,              # Number of groups (for MIRI, # Groups = # Frames)

        ############################################################################################
        # This is where you set up your dither parameters - adjust values spefific to your observation 
        
        Dither = False,             # Don't Dither    
        StartInd = 1,               # Start index for dither pattern 
        NDither = 4,                # Number of dither positions 
        DitherPat = 'mrs_recommended_dither.dat', # Dither pattern to use 
        
        
        ############################################################################################
        # These parameters are not used in the MRS simulation and should not be adjusted (or deleted)
        ima_exposures = 0,           # [NOT USED HERE]
        ima_integrations = 16,       # [NOT USED HERE]
        ima_frames = 14,             # [NOT USED HERE]
        ima_mode = 'FAST',           # [NOT USED HERE]
        filter = 'F1000W',           # [NOT USED HERE]
        readDetect = 'BRIGHTSKY'     # [NOT USED HERE]
        ))
# Out:
# SimConfig populated by:
# MRS_short_SN1987A_simulation : MRS_1SHORT : SHORT : 1 : 3 : 80
# MRS_medium_SN1987A_simulation : MRS_1MEDIUM : MEDIUM : 1 : 3 : 80
# MRS_long_SN1987A_simulation : MRS_1LONG : LONG : 1 : 3 : 80

# %% [markdown]
# ### Export the simulation setup files
#
# Not necessary as saved in mirisim output in the date stamped output directory. Included here as naming each file explicitly for record keeping.

# %%
for sim_object, file_name in zip(sim_objects, sim_filenames):
    os.system('rm {}.ini'.format(file_name))
    sim_object.write("{}.ini".format(file_name))

# %% [markdown]
# ## Run the simulation
#
# Now that the scene and the setup of the simulation have been set, we can run the simulation.
# The last step is to setup the defaults for internal things like CDPs.

# %%
# Get the simulation configuration perameters using the default setup
simulator_config = SimulatorConfig.from_default()

# %%
for sim_object in sim_objects:
    mysim = MiriSimulation(sim_object,scene_config,simulator_config)
    mysim.run()
# Out:
# 2020-02-24 17:35:02,603 - INFO - MIRISim version: 2.2.0dev0
# 2020-02-24 17:35:02,604 - INFO - MIRI Simulation started.
# 2020-02-24 17:35:02,605 - INFO - Output will be saved to: 20200224_173502_mirisim
# 2020-02-24 17:35:02,605 - INFO - Storing configs in output directory.
# 2020-02-24 17:35:06,364 - INFO - Using $CDP_DIR for location of CDP files: //Users/ojones/Data/MIRI_testing
# 2020-02-24 17:35:07,077 - INFO - Reading cosmic ray properties from parameter file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/scasim/cosmic_ray_properties.py
# 2020-02-24 17:35:07,128 - INFO - Reading detector properties from parameter file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/scasim/detector_properties.py
# 2020-02-24 17:35:07,404 - INFO - Setting up simulated Observation, with following settings:
# 2020-02-24 17:35:07,405 - INFO - Configuration Path: MRS_1SHORT
# 2020-02-24 17:35:07,406 - INFO - Primary optical path: MRS
# 2020-02-24 17:35:07,406 - INFO - MRS detector: BOTH
# 2020-02-24 17:35:07,407 - INFO - MRS band: SHORT
# 2020-02-24 17:35:07,408 - INFO - MRS detector readout mode: FAST
# 2020-02-24 17:35:07,410 - INFO - MRS detector # exposures: 1
# 2020-02-24 17:35:07,411 - INFO - MRS detector # integrations: 3
# 2020-02-24 17:35:07,412 - INFO - MRS detector # frames: 80
# 2020-02-24 17:35:07,413 - INFO - Parsing: Background
# 2020-02-24 17:35:07,414 - INFO - Initializing Background
# 2020-02-24 17:35:07,415 - INFO - Parsing: point_1
# 2020-02-24 17:35:07,416 - INFO - Initializing Point
# 2020-02-24 17:35:07,417 - INFO - Parsing: galaxy_1
# 2020-02-24 17:35:07,418 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,419 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,419 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,445 - INFO - Parsing: galaxy_2
# 2020-02-24 17:35:07,446 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,447 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,447 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,473 - INFO - Parsing: galaxy_3
# 2020-02-24 17:35:07,473 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,475 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,475 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,499 - INFO - Parsing: galaxy_4
# 2020-02-24 17:35:07,500 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,501 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,502 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,525 - INFO - Parsing: galaxy_5
# 2020-02-24 17:35:07,526 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,527 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,528 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,553 - INFO - Parsing: galaxy_6
# 2020-02-24 17:35:07,554 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,555 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,556 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,580 - INFO - Parsing: galaxy_7
# 2020-02-24 17:35:07,581 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,582 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,583 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,606 - INFO - Parsing: galaxy_8
# 2020-02-24 17:35:07,607 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,608 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,609 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,633 - INFO - Parsing: galaxy_9
# 2020-02-24 17:35:07,634 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,635 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,636 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,660 - INFO - Parsing: galaxy_10
# 2020-02-24 17:35:07,661 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,662 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,663 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,689 - INFO - Parsing: galaxy_11
# 2020-02-24 17:35:07,690 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,691 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,692 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,716 - INFO - Parsing: galaxy_12
# 2020-02-24 17:35:07,717 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,717 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,718 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,742 - INFO - Parsing: galaxy_13
# 2020-02-24 17:35:07,742 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,743 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,744 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,767 - INFO - Parsing: galaxy_14
# 2020-02-24 17:35:07,768 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,769 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,769 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,793 - INFO - Parsing: galaxy_15
# 2020-02-24 17:35:07,794 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,795 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,795 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,820 - INFO - Parsing: galaxy_16
# 2020-02-24 17:35:07,820 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,821 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,822 - INFO - Initializing Galaxy
# 2020-02-24 17:35:07,846 - INFO - Simulating a single pointing.
# 2020-02-24 17:35:14,866 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:35:17,077 - INFO - Creating pointing for position 1
# 2020-02-24 17:35:17,078 - INFO - Creating exposure event for position 1
# 2020-02-24 17:35:17,089 - INFO - Observation simulation started.
# 2020-02-24 17:35:17,091 - INFO - Simulating ExposureEvent for pointing 1
# 2020-02-24 17:35:17,093 - INFO - Simulating MRS exposures for pointing 1
# 2020-02-24 17:35:17,094 - INFO - Creating skycubes for MRS exposures for pointing 1
# 2020-02-24 17:35:17,096 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:35:19,029 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_1SHORT_PSF_07.02.00.fits'
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# WARNING:astropy:Model is linear in parameters; consider using linear fitting methods.
# 2020-02-24 17:35:38,050 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:35:38,487 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:35:39,171 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:39,329 - INFO - Refining done...
# 2020-02-24 17:35:39,390 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:39,534 - INFO - Refining done...
# 2020-02-24 17:35:39,596 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:39,743 - INFO - Refining done...
# 2020-02-24 17:35:39,803 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:39,950 - INFO - Refining done...
# 2020-02-24 17:35:40,010 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:40,152 - INFO - Refining done...
# 2020-02-24 17:35:40,214 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:40,353 - INFO - Refining done...
# 2020-02-24 17:35:40,413 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:40,558 - INFO - Refining done...
# 2020-02-24 17:35:40,619 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:40,767 - INFO - Refining done...
# 2020-02-24 17:35:40,827 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:40,969 - INFO - Refining done...
# 2020-02-24 17:35:41,030 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:41,175 - INFO - Refining done...
# 2020-02-24 17:35:41,235 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:41,379 - INFO - Refining done...
# 2020-02-24 17:35:41,440 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:41,593 - INFO - Refining done...
# 2020-02-24 17:35:41,653 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:41,797 - INFO - Refining done...
# 2020-02-24 17:35:41,858 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:42,002 - INFO - Refining done...
# 2020-02-24 17:35:42,063 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:42,207 - INFO - Refining done...
# 2020-02-24 17:35:42,267 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:35:42,414 - INFO - Refining done...
# 2020-02-24 17:35:42,444 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_2SHORT_PSF_07.02.00.fits'
# 2020-02-24 17:36:07,176 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:36:07,944 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:36:08,600 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:08,740 - INFO - Refining done...
# 2020-02-24 17:36:08,801 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:08,946 - INFO - Refining done...
# 2020-02-24 17:36:09,008 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:09,155 - INFO - Refining done...
# 2020-02-24 17:36:09,217 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:09,364 - INFO - Refining done...
# 2020-02-24 17:36:09,426 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:09,572 - INFO - Refining done...
# 2020-02-24 17:36:09,635 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:09,784 - INFO - Refining done...
# 2020-02-24 17:36:09,845 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:09,991 - INFO - Refining done...
# 2020-02-24 17:36:10,055 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:10,216 - INFO - Refining done...
# 2020-02-24 17:36:10,278 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:10,426 - INFO - Refining done...
# 2020-02-24 17:36:10,488 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:10,636 - INFO - Refining done...
# 2020-02-24 17:36:10,696 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:10,846 - INFO - Refining done...
# 2020-02-24 17:36:10,908 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:11,057 - INFO - Refining done...
# 2020-02-24 17:36:11,119 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:11,269 - INFO - Refining done...
# 2020-02-24 17:36:11,330 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:11,479 - INFO - Refining done...
# 2020-02-24 17:36:11,540 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:11,689 - INFO - Refining done...
# 2020-02-24 17:36:11,750 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:11,898 - INFO - Refining done...
# 2020-02-24 17:36:11,932 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_3SHORT_PSF_07.02.00.fits'
# 2020-02-24 17:36:44,988 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:36:45,393 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:36:45,977 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,075 - INFO - Refining done...
# 2020-02-24 17:36:46,118 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,216 - INFO - Refining done...
# 2020-02-24 17:36:46,261 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,360 - INFO - Refining done...
# 2020-02-24 17:36:46,403 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,501 - INFO - Refining done...
# 2020-02-24 17:36:46,545 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,641 - INFO - Refining done...
# 2020-02-24 17:36:46,684 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,779 - INFO - Refining done...
# 2020-02-24 17:36:46,823 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:46,922 - INFO - Refining done...
# 2020-02-24 17:36:46,965 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,065 - INFO - Refining done...
# 2020-02-24 17:36:47,107 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,207 - INFO - Refining done...
# 2020-02-24 17:36:47,251 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,351 - INFO - Refining done...
# 2020-02-24 17:36:47,395 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,496 - INFO - Refining done...
# 2020-02-24 17:36:47,541 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,641 - INFO - Refining done...
# 2020-02-24 17:36:47,684 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,785 - INFO - Refining done...
# 2020-02-24 17:36:47,828 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:47,928 - INFO - Refining done...
# 2020-02-24 17:36:47,973 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:48,074 - INFO - Refining done...
# 2020-02-24 17:36:48,117 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:36:48,218 - INFO - Refining done...
# 2020-02-24 17:36:48,242 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_4SHORT_PSF_07.02.00.fits'
# 2020-02-24 17:37:16,636 - INFO - Wrote skycube: 20200224_173502_mirisim/skycubes/skycube_seq1_1SHORT.fits
# 2020-02-24 17:37:16,696 - INFO - Wrote skycube: 20200224_173502_mirisim/skycubes/skycube_seq1_2SHORT.fits
# 2020-02-24 17:37:16,752 - INFO - Wrote skycube: 20200224_173502_mirisim/skycubes/skycube_seq1_3SHORT.fits
# 2020-02-24 17:37:16,791 - INFO - Wrote skycube: 20200224_173502_mirisim/skycubes/skycube_seq1_4SHORT.fits
# 2020-02-24 17:37:16,793 - INFO - Simulating detector illumination for MRS exposures for pointing 1
# 2020-02-24 17:37:16,797 - INFO - Starting pySpecSimMiri
# 2020-02-24 17:37:16,869 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-24 17:37:16,870 - INFO - Instrument setup starting.
# 2020-02-24 17:37:16,871 - INFO - Detector setup starting.
# 2020-02-24 17:37:16,872 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-24 17:37:16,874 - INFO - MRS light path simulation starting.
# 2020-02-24 17:37:16,875 - INFO - Simulating Instrument.
# 2020-02-24 17:37:16,899 - INFO - Simulating Detector.
# 2020-02-24 17:37:16,900 - INFO - Simulating Detector Mapping for channel ['1'] and band SHORT
# 2020-02-24 17:37:16,901 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:37:16,903 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:37:17,556 - INFO - Valid cache found.
# 2020-02-24 17:37:17,559 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:37:29,329 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:38:48,507 - INFO - Mapping completed
# 2020-02-24 17:38:48,508 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:38:49,179 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_FRINGE_07.02.05.fits'
# 2020-02-24 17:38:49,393 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_PHOTOM_07.03.00.fits'
# 2020-02-24 17:38:49,539 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 17:38:49,622 - INFO - Simulating Detector Mapping for channel ['2'] and band SHORT
# 2020-02-24 17:38:49,623 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:38:49,625 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:38:50,060 - INFO - Valid cache found.
# 2020-02-24 17:38:50,062 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:39:01,532 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:40:21,284 - INFO - Mapping completed
# 2020-02-24 17:40:21,285 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:40:21,782 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_FRINGE_07.02.05.fits'
# 2020-02-24 17:40:21,924 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_PHOTOM_07.03.00.fits'
# 2020-02-24 17:40:22,039 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 17:40:22,080 - INFO - MRS light path simulation finished.
# 2020-02-24 17:40:22,118 - INFO - Added 1 Cube to output list
# 2020-02-24 17:40:22,121 - INFO - Added 2 Cube to output list
# 2020-02-24 17:40:22,224 - INFO - Starting pySpecSimMiri
# 2020-02-24 17:40:22,234 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-24 17:40:22,235 - INFO - Instrument setup starting.
# 2020-02-24 17:40:22,237 - INFO - Detector setup starting.
# 2020-02-24 17:40:22,238 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-24 17:40:22,239 - INFO - MRS light path simulation starting.
# 2020-02-24 17:40:22,240 - INFO - Simulating Instrument.
# 2020-02-24 17:40:22,251 - INFO - Simulating Detector.
# 2020-02-24 17:40:22,251 - INFO - Simulating Detector Mapping for channel ['3'] and band SHORT
# 2020-02-24 17:40:22,252 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:40:22,255 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:40:22,713 - INFO - Valid cache found.
# 2020-02-24 17:40:22,716 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:40:34,444 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:41:54,854 - INFO - Mapping completed
# 2020-02-24 17:41:54,855 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:41:55,280 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_FRINGE_07.02.00.fits'
# 2020-02-24 17:41:55,436 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_PHOTOM_07.03.00.fits'
# 2020-02-24 17:41:55,680 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 17:41:55,737 - INFO - Simulating Detector Mapping for channel ['4'] and band SHORT
# 2020-02-24 17:41:55,738 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:41:55,740 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:41:56,117 - INFO - Valid cache found.
# 2020-02-24 17:41:56,118 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:42:04,005 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:42:59,145 - INFO - Mapping completed
# 2020-02-24 17:42:59,146 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:42:59,469 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_FRINGE_07.02.00.fits'
# 2020-02-24 17:42:59,604 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_PHOTOM_07.03.00.fits'
# 2020-02-24 17:42:59,704 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 17:42:59,733 - INFO - MRS light path simulation finished.
# 2020-02-24 17:42:59,742 - INFO - Added 3 Cube to output list
# 2020-02-24 17:42:59,743 - INFO - Added 4 Cube to output list
# 2020-02-24 17:42:59,987 - INFO - Wrote illumination model: 20200224_173502_mirisim/illum_models/illum_model_seq1_MIRIFUSHORT_12SHORT.fits
# 2020-02-24 17:43:00,042 - INFO - Wrote illumination model: 20200224_173502_mirisim/illum_models/illum_model_seq1_MIRIFULONG_34SHORT.fits
# 2020-02-24 17:43:00,043 - INFO - Simulating integrated detector images for MRS exposures for pointing 1
# 2020-02-24 17:43:00,044 - INFO - Simulating MRS exposure 1
# 2020-02-24 17:43:00,047 - INFO - Running SCASim
# 2020-02-24 17:43:00,049 - INFO - Simulating  detector readout for MIRIFUSHORT from illumination data model of shape (1024, 1024).
# 2020-02-24 17:43:00,064 - INFO - Results will be returned in an exposure data model.
# 2020-02-24 17:43:00,084 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-24 17:43:00,085 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-24 17:43:00,086 - INFO -   Detector subarray mode is FULL.
# 2020-02-24 17:43:00,087 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-24 17:43:00,088 - INFO - Cosmic ray environment is SOLAR_MIN.
# 2020-02-24 17:43:00,089 - INFO - Reading cosmic ray library file: '/Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/data/cosmic_rays/CRs_SiAs_470_SUNMIN_08.fits'
# 2020-02-24 17:43:00,166 - INFO - Simulation control flags:
# 2020-02-24 17:43:00,168 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-24 17:43:00,168 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-24 17:43:00,169 - INFO - 	Read noise simulation turned ON.
# 2020-02-24 17:43:00,170 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-24 17:43:00,171 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-24 17:43:00,172 - INFO - 	Dark current simulation turned ON.
# 2020-02-24 17:43:00,172 - INFO - 	Flat-field simulation turned ON.
# 2020-02-24 17:43:00,173 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-24 17:43:00,174 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-24 17:43:00,175 - INFO - 	Detector drift effects turned ON.
# 2020-02-24 17:43:00,176 - INFO - 	Detector latency effects turned ON.
# 2020-02-24 17:43:00,178 - INFO - Creating a new detector object for 1024 rows x 1024 columns.
# 2020-02-24 17:43:00,187 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_MASK_07.02.01.fits'
# 2020-02-24 17:43:00,283 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 17:43:05,397 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits'
# 2020-02-24 17:43:05,656 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_FLAT_8B.01.00.fits'
# 2020-02-24 17:43:05,792 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFUSHORT with FAST mode with band='SHORT'. An alternative is being used.
# 2020-02-24 17:43:05,824 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits'
# 2020-02-24 17:43:06,091 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_READNOISE_07.01.00.fits'
# 2020-02-24 17:43:06,158 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-24 17:43:06,299 - INFO - Simulating 3 integrations.
# 2020-02-24 17:43:06,306 - WARNING - ***Input flux array contains 1 negative values.
# 2020-02-24 17:43:06,376 - INFO - Simulating 80 groups for integration 1.
# 2020-02-24 17:43:24,822 - INFO - Simulating 80 groups for integration 2.
# 2020-02-24 17:43:43,809 - INFO - Simulating 80 groups for integration 3.
# 2020-02-24 17:44:03,059 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits
# 2020-02-24 17:44:08,410 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits
# 2020-02-24 17:44:25,328 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-24 17:44:41,230 - INFO - Wrote detector image: 20200224_173502_mirisim/det_images/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits
# 2020-02-24 17:44:41,231 - INFO - Simulating MRS exposure 1
# 2020-02-24 17:44:41,235 - INFO - Running SCASim
# 2020-02-24 17:44:41,235 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2020-02-24 17:44:41,249 - INFO - Results will be returned in an exposure data model.
# 2020-02-24 17:44:41,267 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-24 17:44:41,268 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-24 17:44:41,268 - INFO -   Detector subarray mode is FULL.
# 2020-02-24 17:44:41,269 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-24 17:44:41,270 - INFO - Cosmic ray environment is SOLAR_MIN.
# 2020-02-24 17:44:41,271 - INFO - Reading cosmic ray library file: '/Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/data/cosmic_rays/CRs_SiAs_470_SUNMIN_04.fits'
# 2020-02-24 17:44:41,347 - INFO - Simulation control flags:
# 2020-02-24 17:44:41,348 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-24 17:44:41,349 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-24 17:44:41,350 - INFO - 	Read noise simulation turned ON.
# 2020-02-24 17:44:41,351 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-24 17:44:41,351 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-24 17:44:41,353 - INFO - 	Dark current simulation turned ON.
# 2020-02-24 17:44:41,354 - INFO - 	Flat-field simulation turned ON.
# 2020-02-24 17:44:41,355 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-24 17:44:41,356 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-24 17:44:41,356 - INFO - 	Detector drift effects turned ON.
# 2020-02-24 17:44:41,357 - INFO - 	Detector latency effects turned ON.
# 2020-02-24 17:44:41,360 - INFO - Creating a new detector object for 1024 rows x 1024 columns.
# 2020-02-24 17:44:41,374 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2020-02-24 17:44:41,443 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 17:44:41,491 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2020-02-24 17:44:41,683 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_FLAT_8B.01.00.fits'
# 2020-02-24 17:44:41,805 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='SHORT'. An alternative is being used.
# 2020-02-24 17:44:41,839 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits'
# 2020-02-24 17:44:42,087 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2020-02-24 17:44:42,145 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-24 17:44:42,253 - INFO - Simulating 3 integrations.
# 2020-02-24 17:44:42,260 - WARNING - ***Input flux array contains 2 negative values.
# 2020-02-24 17:44:42,326 - INFO - Simulating 80 groups for integration 1.
# 2020-02-24 17:45:02,689 - INFO - Simulating 80 groups for integration 2.
# 2020-02-24 17:45:22,965 - INFO - Simulating 80 groups for integration 3.
# 2020-02-24 17:45:42,852 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2020-02-24 17:45:48,402 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits
# 2020-02-24 17:46:06,592 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-24 17:46:22,360 - INFO - Wrote detector image: 20200224_173502_mirisim/det_images/det_image_seq1_MIRIFULONG_34SHORTexp1.fits
# 2020-02-24 17:46:22,362 - INFO - MIRI Simulation finished. Results have been saved to: 20200224_173502_mirisim
#
# 2020-02-24 17:46:22,367 - INFO - MIRISim version: 2.2.0dev0
# 2020-02-24 17:46:22,368 - INFO - MIRI Simulation started.
# 2020-02-24 17:46:22,369 - INFO - Output will be saved to: 20200224_174622_mirisim
# 2020-02-24 17:46:22,370 - INFO - Storing configs in output directory.
# 2020-02-24 17:46:22,375 - INFO - Using $CDP_DIR for location of CDP files: //Users/ojones/Data/MIRI_testing
# 2020-02-24 17:46:22,376 - INFO -
# 2020-02-24 17:46:22,377 - INFO - 	*** Detector hard reset. NOTE: All latency and drift data will be erased.
# 2020-02-24 17:46:22,448 - INFO -
# 2020-02-24 17:46:22,449 - INFO - 	*** Detector hard reset. NOTE: All latency and drift data will be erased.
# 2020-02-24 17:46:22,510 - INFO - Setting up simulated Observation, with following settings:
# 2020-02-24 17:46:22,511 - INFO - Configuration Path: MRS_1MEDIUM
# 2020-02-24 17:46:22,513 - INFO - Primary optical path: MRS
# 2020-02-24 17:46:22,513 - INFO - MRS detector: BOTH
# 2020-02-24 17:46:22,515 - INFO - MRS band: MEDIUM
# 2020-02-24 17:46:22,516 - INFO - MRS detector readout mode: FAST
# 2020-02-24 17:46:22,517 - INFO - MRS detector # exposures: 1
# 2020-02-24 17:46:22,518 - INFO - MRS detector # integrations: 3
# 2020-02-24 17:46:22,519 - INFO - MRS detector # frames: 80
# 2020-02-24 17:46:22,521 - INFO - Parsing: Background
# 2020-02-24 17:46:22,522 - INFO - Initializing Background
# 2020-02-24 17:46:22,523 - INFO - Parsing: point_1
# 2020-02-24 17:46:22,525 - INFO - Initializing Point
# 2020-02-24 17:46:22,526 - INFO - Parsing: galaxy_1
# 2020-02-24 17:46:22,527 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,528 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,529 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,559 - INFO - Parsing: galaxy_2
# 2020-02-24 17:46:22,560 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,561 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,562 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,588 - INFO - Parsing: galaxy_3
# 2020-02-24 17:46:22,589 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,590 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,592 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,619 - INFO - Parsing: galaxy_4
# 2020-02-24 17:46:22,620 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,621 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,622 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,651 - INFO - Parsing: galaxy_5
# 2020-02-24 17:46:22,653 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,654 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,655 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,685 - INFO - Parsing: galaxy_6
# 2020-02-24 17:46:22,686 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,687 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,687 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,800 - INFO - Parsing: galaxy_7
# 2020-02-24 17:46:22,802 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,803 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,804 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,829 - INFO - Parsing: galaxy_8
# 2020-02-24 17:46:22,831 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,831 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,832 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,857 - INFO - Parsing: galaxy_9
# 2020-02-24 17:46:22,858 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,859 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,860 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,885 - INFO - Parsing: galaxy_10
# 2020-02-24 17:46:22,886 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,887 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,888 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,914 - INFO - Parsing: galaxy_11
# 2020-02-24 17:46:22,915 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,916 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,917 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,942 - INFO - Parsing: galaxy_12
# 2020-02-24 17:46:22,943 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,944 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,945 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,972 - INFO - Parsing: galaxy_13
# 2020-02-24 17:46:22,973 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,975 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,975 - INFO - Initializing Galaxy
# 2020-02-24 17:46:22,999 - INFO - Parsing: galaxy_14
# 2020-02-24 17:46:23,000 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,001 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,002 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,026 - INFO - Parsing: galaxy_15
# 2020-02-24 17:46:23,027 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,028 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,029 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,054 - INFO - Parsing: galaxy_16
# 2020-02-24 17:46:23,055 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,056 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,057 - INFO - Initializing Galaxy
# 2020-02-24 17:46:23,081 - INFO - Simulating a single pointing.
# 2020-02-24 17:46:23,090 - INFO - Creating pointing for position 1
# 2020-02-24 17:46:23,091 - INFO - Creating exposure event for position 1
# 2020-02-24 17:46:23,094 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:46:23,667 - INFO - Observation simulation started.
# 2020-02-24 17:46:23,669 - INFO - Simulating ExposureEvent for pointing 1
# 2020-02-24 17:46:23,670 - INFO - Simulating MRS exposures for pointing 1
# 2020-02-24 17:46:23,671 - INFO - Creating skycubes for MRS exposures for pointing 1
# 2020-02-24 17:46:23,674 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:46:25,582 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_1MEDIUM_PSF_07.02.00.fits'
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# WARNING:astropy:Model is linear in parameters; consider using linear fitting methods.
# 2020-02-24 17:46:46,845 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:46:47,260 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:46:48,006 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:48,150 - INFO - Refining done...
# 2020-02-24 17:46:48,215 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:48,365 - INFO - Refining done...
# 2020-02-24 17:46:48,428 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:48,569 - INFO - Refining done...
# 2020-02-24 17:46:48,629 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:48,773 - INFO - Refining done...
# 2020-02-24 17:46:48,837 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:48,981 - INFO - Refining done...
# 2020-02-24 17:46:49,041 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:49,190 - INFO - Refining done...
# 2020-02-24 17:46:49,250 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:49,395 - INFO - Refining done...
# 2020-02-24 17:46:49,455 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:49,602 - INFO - Refining done...
# 2020-02-24 17:46:49,665 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:49,814 - INFO - Refining done...
# 2020-02-24 17:46:49,878 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:50,032 - INFO - Refining done...
# 2020-02-24 17:46:50,093 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:50,237 - INFO - Refining done...
# 2020-02-24 17:46:50,300 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:50,446 - INFO - Refining done...
# 2020-02-24 17:46:50,509 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:50,652 - INFO - Refining done...
# 2020-02-24 17:46:50,714 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:50,866 - INFO - Refining done...
# 2020-02-24 17:46:50,942 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:51,086 - INFO - Refining done...
# 2020-02-24 17:46:51,149 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:46:51,291 - INFO - Refining done...
# 2020-02-24 17:46:51,320 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_2MEDIUM_PSF_07.02.00.fits'
# 2020-02-24 17:47:16,691 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:47:17,514 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:47:18,182 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:18,324 - INFO - Refining done...
# 2020-02-24 17:47:18,387 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:18,535 - INFO - Refining done...
# 2020-02-24 17:47:18,599 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:18,745 - INFO - Refining done...
# 2020-02-24 17:47:18,808 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:18,957 - INFO - Refining done...
# 2020-02-24 17:47:19,021 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:19,167 - INFO - Refining done...
# 2020-02-24 17:47:19,228 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:19,377 - INFO - Refining done...
# 2020-02-24 17:47:19,442 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:19,589 - INFO - Refining done...
# 2020-02-24 17:47:19,649 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:19,799 - INFO - Refining done...
# 2020-02-24 17:47:19,861 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:20,015 - INFO - Refining done...
# 2020-02-24 17:47:20,077 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:20,229 - INFO - Refining done...
# 2020-02-24 17:47:20,295 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:20,449 - INFO - Refining done...
# 2020-02-24 17:47:20,511 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:20,671 - INFO - Refining done...
# 2020-02-24 17:47:20,735 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:20,895 - INFO - Refining done...
# 2020-02-24 17:47:20,965 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:21,128 - INFO - Refining done...
# 2020-02-24 17:47:21,195 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:21,366 - INFO - Refining done...
# 2020-02-24 17:47:21,434 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:21,597 - INFO - Refining done...
# 2020-02-24 17:47:21,629 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_3MEDIUM_PSF_07.02.00.fits'
# 2020-02-24 17:47:55,950 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:47:56,366 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:47:56,951 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,045 - INFO - Refining done...
# 2020-02-24 17:47:57,092 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,190 - INFO - Refining done...
# 2020-02-24 17:47:57,235 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,337 - INFO - Refining done...
# 2020-02-24 17:47:57,381 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,478 - INFO - Refining done...
# 2020-02-24 17:47:57,524 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,624 - INFO - Refining done...
# 2020-02-24 17:47:57,667 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,766 - INFO - Refining done...
# 2020-02-24 17:47:57,809 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:57,907 - INFO - Refining done...
# 2020-02-24 17:47:57,951 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,051 - INFO - Refining done...
# 2020-02-24 17:47:58,095 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,196 - INFO - Refining done...
# 2020-02-24 17:47:58,239 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,339 - INFO - Refining done...
# 2020-02-24 17:47:58,383 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,485 - INFO - Refining done...
# 2020-02-24 17:47:58,527 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,629 - INFO - Refining done...
# 2020-02-24 17:47:58,673 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,774 - INFO - Refining done...
# 2020-02-24 17:47:58,817 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:58,917 - INFO - Refining done...
# 2020-02-24 17:47:58,960 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:59,058 - INFO - Refining done...
# 2020-02-24 17:47:59,101 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:47:59,200 - INFO - Refining done...
# 2020-02-24 17:47:59,224 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_4MEDIUM_PSF_07.02.00.fits'
# 2020-02-24 17:48:30,745 - INFO - Wrote skycube: 20200224_174622_mirisim/skycubes/skycube_seq1_1MEDIUM.fits
# 2020-02-24 17:48:30,811 - INFO - Wrote skycube: 20200224_174622_mirisim/skycubes/skycube_seq1_2MEDIUM.fits
# 2020-02-24 17:48:30,860 - INFO - Wrote skycube: 20200224_174622_mirisim/skycubes/skycube_seq1_3MEDIUM.fits
# 2020-02-24 17:48:30,901 - INFO - Wrote skycube: 20200224_174622_mirisim/skycubes/skycube_seq1_4MEDIUM.fits
# 2020-02-24 17:48:30,902 - INFO - Simulating detector illumination for MRS exposures for pointing 1
# 2020-02-24 17:48:30,907 - INFO - Starting pySpecSimMiri
# 2020-02-24 17:48:30,939 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-24 17:48:30,941 - INFO - Instrument setup starting.
# 2020-02-24 17:48:30,941 - INFO - Detector setup starting.
# 2020-02-24 17:48:30,944 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-24 17:48:30,946 - INFO - MRS light path simulation starting.
# 2020-02-24 17:48:30,947 - INFO - Simulating Instrument.
# 2020-02-24 17:48:30,972 - INFO - Simulating Detector.
# 2020-02-24 17:48:30,973 - INFO - Simulating Detector Mapping for channel ['1'] and band MEDIUM
# 2020-02-24 17:48:30,974 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:48:30,977 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:48:31,565 - INFO - Valid cache found.
# 2020-02-24 17:48:31,567 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:48:43,266 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:50:03,032 - INFO - Mapping completed
# 2020-02-24 17:50:03,033 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:50:03,701 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_FRINGE_07.02.05.fits'
# 2020-02-24 17:50:03,881 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-24 17:50:04,011 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 17:50:04,213 - INFO - Simulating Detector Mapping for channel ['2'] and band MEDIUM
# 2020-02-24 17:50:04,214 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:50:04,215 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:50:04,604 - INFO - Valid cache found.
# 2020-02-24 17:50:04,607 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:50:16,232 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:51:33,281 - INFO - Mapping completed
# 2020-02-24 17:51:33,282 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:51:33,749 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_FRINGE_07.02.05.fits'
# 2020-02-24 17:51:33,891 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-24 17:51:33,996 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 17:51:34,026 - INFO - MRS light path simulation finished.
# 2020-02-24 17:51:34,037 - INFO - Added 1 Cube to output list
# 2020-02-24 17:51:34,038 - INFO - Added 2 Cube to output list
# 2020-02-24 17:51:34,137 - INFO - Starting pySpecSimMiri
# 2020-02-24 17:51:34,147 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-24 17:51:34,147 - INFO - Instrument setup starting.
# 2020-02-24 17:51:34,149 - INFO - Detector setup starting.
# 2020-02-24 17:51:34,150 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-24 17:51:34,152 - INFO - MRS light path simulation starting.
# 2020-02-24 17:51:34,153 - INFO - Simulating Instrument.
# 2020-02-24 17:51:34,162 - INFO - Simulating Detector.
# 2020-02-24 17:51:34,163 - INFO - Simulating Detector Mapping for channel ['3'] and band MEDIUM
# 2020-02-24 17:51:34,163 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:51:34,166 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:51:34,615 - INFO - Valid cache found.
# 2020-02-24 17:51:34,618 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:51:46,635 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:53:06,189 - INFO - Mapping completed
# 2020-02-24 17:53:06,190 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:53:06,698 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits'
# 2020-02-24 17:53:06,876 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-24 17:53:07,021 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 17:53:07,079 - INFO - Simulating Detector Mapping for channel ['4'] and band MEDIUM
# 2020-02-24 17:53:07,080 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:53:07,082 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:53:07,455 - INFO - Valid cache found.
# 2020-02-24 17:53:07,457 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:53:15,354 - INFO - Starting pixel projection with cache.
# 2020-02-24 17:54:09,304 - INFO - Mapping completed
# 2020-02-24 17:54:09,305 - INFO - Detector Intensity Array completed.
# 2020-02-24 17:54:09,628 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits'
# 2020-02-24 17:54:09,753 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-24 17:54:09,858 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 17:54:09,888 - INFO - MRS light path simulation finished.
# ...
# 2020-02-24 17:58:52,854 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:52,954 - INFO - Refining done...
# 2020-02-24 17:58:53,009 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:53,133 - INFO - Refining done...
# 2020-02-24 17:58:53,183 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:53,291 - INFO - Refining done...
# 2020-02-24 17:58:53,334 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:53,431 - INFO - Refining done...
# 2020-02-24 17:58:53,473 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:53,570 - INFO - Refining done...
# 2020-02-24 17:58:53,614 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:53,718 - INFO - Refining done...
# 2020-02-24 17:58:53,763 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:53,867 - INFO - Refining done...
# 2020-02-24 17:58:53,915 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:54,017 - INFO - Refining done...
# 2020-02-24 17:58:54,059 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:54,157 - INFO - Refining done...
# 2020-02-24 17:58:54,199 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:54,302 - INFO - Refining done...
# 2020-02-24 17:58:54,346 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:54,444 - INFO - Refining done...
# 2020-02-24 17:58:54,486 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:54,585 - INFO - Refining done...
# 2020-02-24 17:58:54,627 - INFO - Refining due to small radius 0.150000 ...
# 2020-02-24 17:58:54,723 - INFO - Refining done...
# 2020-02-24 17:58:54,750 - INFO - Reading 'PSF' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_4LONG_PSF_07.02.00.fits'
# 2020-02-24 17:59:22,899 - INFO - Wrote skycube: 20200224_175716_mirisim/skycubes/skycube_seq1_1LONG.fits
# 2020-02-24 17:59:22,950 - INFO - Wrote skycube: 20200224_175716_mirisim/skycubes/skycube_seq1_2LONG.fits
# 2020-02-24 17:59:22,999 - INFO - Wrote skycube: 20200224_175716_mirisim/skycubes/skycube_seq1_3LONG.fits
# 2020-02-24 17:59:23,044 - INFO - Wrote skycube: 20200224_175716_mirisim/skycubes/skycube_seq1_4LONG.fits
# 2020-02-24 17:59:23,046 - INFO - Simulating detector illumination for MRS exposures for pointing 1
# 2020-02-24 17:59:23,050 - INFO - Starting pySpecSimMiri
# 2020-02-24 17:59:23,080 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-24 17:59:23,081 - INFO - Instrument setup starting.
# 2020-02-24 17:59:23,081 - INFO - Detector setup starting.
# 2020-02-24 17:59:23,083 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-24 17:59:23,085 - INFO - MRS light path simulation starting.
# 2020-02-24 17:59:23,086 - INFO - Simulating Instrument.
# 2020-02-24 17:59:23,105 - INFO - Simulating Detector.
# 2020-02-24 17:59:23,105 - INFO - Simulating Detector Mapping for channel ['1'] and band LONG
# 2020-02-24 17:59:23,106 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 17:59:23,109 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_DISTORTION_8B.05.01.fits'
# 2020-02-24 17:59:23,533 - INFO - Valid cache found.
# 2020-02-24 17:59:23,535 - INFO - Starting Coordinate Transformation
# 2020-02-24 17:59:34,894 - INFO - Starting pixel projection with cache.
# 2020-02-24 18:00:46,228 - INFO - Mapping completed
# 2020-02-24 18:00:46,229 - INFO - Detector Intensity Array completed.
# 2020-02-24 18:00:46,890 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_FRINGE_07.02.05.fits'
# 2020-02-24 18:00:47,061 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_PHOTOM_07.03.00.fits'
# 2020-02-24 18:00:47,178 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 18:00:47,230 - INFO - Simulating Detector Mapping for channel ['2'] and band LONG
# 2020-02-24 18:00:47,231 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 18:00:47,233 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_DISTORTION_8B.05.01.fits'
# 2020-02-24 18:00:47,625 - INFO - Valid cache found.
# 2020-02-24 18:00:47,628 - INFO - Starting Coordinate Transformation
# 2020-02-24 18:00:58,933 - INFO - Starting pixel projection with cache.
# 2020-02-24 18:02:14,838 - INFO - Mapping completed
# 2020-02-24 18:02:14,839 - INFO - Detector Intensity Array completed.
# 2020-02-24 18:02:15,389 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_FRINGE_07.02.05.fits'
# 2020-02-24 18:02:15,531 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_PHOTOM_07.03.00.fits'
# 2020-02-24 18:02:15,634 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 18:02:15,662 - INFO - MRS light path simulation finished.
# 2020-02-24 18:02:15,672 - INFO - Added 1 Cube to output list
# 2020-02-24 18:02:15,673 - INFO - Added 2 Cube to output list
# 2020-02-24 18:02:15,766 - INFO - Starting pySpecSimMiri
# 2020-02-24 18:02:15,776 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-24 18:02:15,778 - INFO - Instrument setup starting.
# 2020-02-24 18:02:15,779 - INFO - Detector setup starting.
# 2020-02-24 18:02:15,780 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-24 18:02:15,782 - INFO - MRS light path simulation starting.
# 2020-02-24 18:02:15,783 - INFO - Simulating Instrument.
# 2020-02-24 18:02:15,794 - INFO - Simulating Detector.
# 2020-02-24 18:02:15,795 - INFO - Simulating Detector Mapping for channel ['3'] and band LONG
# 2020-02-24 18:02:15,796 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 18:02:15,798 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_DISTORTION_8B.05.01.fits'
# 2020-02-24 18:02:16,247 - INFO - Valid cache found.
# 2020-02-24 18:02:16,249 - INFO - Starting Coordinate Transformation
# 2020-02-24 18:02:28,081 - INFO - Starting pixel projection with cache.
# 2020-02-24 18:03:45,614 - INFO - Mapping completed
# 2020-02-24 18:03:45,616 - INFO - Detector Intensity Array completed.
# 2020-02-24 18:03:46,039 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_FRINGE_07.02.00.fits'
# 2020-02-24 18:03:46,222 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_PHOTOM_07.03.00.fits'
# 2020-02-24 18:03:46,355 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 18:03:46,417 - INFO - Simulating Detector Mapping for channel ['4'] and band LONG
# 2020-02-24 18:03:46,418 - INFO - Getting Coefficients and Substitute values
# 2020-02-24 18:03:46,420 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_DISTORTION_8B.05.01.fits'
# 2020-02-24 18:03:46,810 - INFO - Valid cache found.
# 2020-02-24 18:03:46,812 - INFO - Starting Coordinate Transformation
# 2020-02-24 18:03:54,435 - INFO - Starting pixel projection with cache.
# 2020-02-24 18:04:46,670 - INFO - Mapping completed
# 2020-02-24 18:04:46,671 - INFO - Detector Intensity Array completed.
# 2020-02-24 18:04:47,018 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_FRINGE_07.02.00.fits'
# 2020-02-24 18:04:47,162 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_PHOTOM_07.03.00.fits'
# 2020-02-24 18:04:47,267 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 18:04:47,296 - INFO - MRS light path simulation finished.
# 2020-02-24 18:04:47,305 - INFO - Added 3 Cube to output list
# 2020-02-24 18:04:47,305 - INFO - Added 4 Cube to output list
# 2020-02-24 18:04:47,470 - INFO - Wrote illumination model: 20200224_175716_mirisim/illum_models/illum_model_seq1_MIRIFUSHORT_12LONG.fits
# 2020-02-24 18:04:47,530 - INFO - Wrote illumination model: 20200224_175716_mirisim/illum_models/illum_model_seq1_MIRIFULONG_34LONG.fits
# 2020-02-24 18:04:47,532 - INFO - Simulating integrated detector images for MRS exposures for pointing 1
# 2020-02-24 18:04:47,534 - INFO - Simulating MRS exposure 1
# 2020-02-24 18:04:47,537 - INFO - Running SCASim
# 2020-02-24 18:04:47,538 - INFO - Simulating  detector readout for MIRIFUSHORT from illumination data model of shape (1024, 1024).
# 2020-02-24 18:04:47,551 - INFO - Results will be returned in an exposure data model.
# 2020-02-24 18:04:47,570 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-24 18:04:47,571 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-24 18:04:47,572 - INFO -   Detector subarray mode is FULL.
# 2020-02-24 18:04:47,573 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-24 18:04:47,574 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2020-02-24 18:04:47,575 - INFO - Simulation control flags:
# 2020-02-24 18:04:47,576 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-24 18:04:47,577 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-24 18:04:47,578 - INFO - 	Read noise simulation turned ON.
# 2020-02-24 18:04:47,579 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-24 18:04:47,579 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-24 18:04:47,580 - INFO - 	Dark current simulation turned ON.
# 2020-02-24 18:04:47,581 - INFO - 	Flat-field simulation turned ON.
# 2020-02-24 18:04:47,581 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-24 18:04:47,582 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-24 18:04:47,582 - INFO - 	Detector drift effects turned ON.
# 2020-02-24 18:04:47,583 - INFO - 	Detector latency effects turned ON.
# 2020-02-24 18:04:47,587 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_MASK_07.02.01.fits'
# 2020-02-24 18:04:47,685 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-24 18:04:47,763 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits'
# 2020-02-24 18:04:47,893 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_FLAT_8B.01.00.fits'
# 2020-02-24 18:04:48,016 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFUSHORT with FAST mode with band='LONG'. An alternative is being used.
# 2020-02-24 18:04:48,048 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits'
# 2020-02-24 18:04:48,286 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_READNOISE_07.01.00.fits'
# 2020-02-24 18:04:48,352 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-24 18:04:48,450 - INFO - Simulating 3 integrations.
# 2020-02-24 18:04:48,457 - WARNING - ***Input flux array contains 1 negative values.
# 2020-02-24 18:04:48,549 - INFO - Simulating 80 groups for integration 1.
# 2020-02-24 18:05:06,736 - INFO - Simulating 80 groups for integration 2.
# 2020-02-24 18:05:25,491 - INFO - Simulating 80 groups for integration 3.
# 2020-02-24 18:05:43,978 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits
# 2020-02-24 18:05:47,526 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits
# 2020-02-24 18:06:01,402 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-24 18:06:16,786 - INFO - Wrote detector image: 20200224_175716_mirisim/det_images/det_image_seq1_MIRIFUSHORT_12LONGexp1.fits
# 2020-02-24 18:06:16,787 - INFO - Simulating MRS exposure 1
# 2020-02-24 18:06:16,791 - INFO - Running SCASim
# 2020-02-24 18:06:16,792 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2020-02-24 18:06:16,805 - INFO - Results will be returned in an exposure data model.
# 2020-02-24 18:06:16,821 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-24 18:06:16,822 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-24 18:06:16,822 - INFO -   Detector subarray mode is FULL.
# 2020-02-24 18:06:16,824 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-24 18:06:16,825 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2020-02-24 18:06:16,825 - INFO - Simulation control flags:
# 2020-02-24 18:06:16,826 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-24 18:06:16,827 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-24 18:06:16,828 - INFO - 	Read noise simulation turned ON.
# 2020-02-24 18:06:16,829 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-24 18:06:16,830 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-24 18:06:16,830 - INFO - 	Dark current simulation turned ON.
# 2020-02-24 18:06:16,831 - INFO - 	Flat-field simulation turned ON.
# 2020-02-24 18:06:16,832 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-24 18:06:16,833 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-24 18:06:16,834 - INFO - 	Detector drift effects turned ON.
# 2020-02-24 18:06:16,834 - INFO - 	Detector latency effects turned ON.
# 2020-02-24 18:06:16,838 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2020-02-24 18:06:16,925 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-24 18:06:17,001 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2020-02-24 18:06:17,140 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_FLAT_8B.01.00.fits'
# 2020-02-24 18:06:17,251 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='LONG'. An alternative is being used.
# 2020-02-24 18:06:17,281 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits'
# 2020-02-24 18:06:17,540 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2020-02-24 18:06:17,607 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-24 18:06:17,714 - INFO - Simulating 3 integrations.
# 2020-02-24 18:06:17,721 - WARNING - ***Input flux array contains 6822 negative values.
# 2020-02-24 18:06:17,797 - INFO - Simulating 80 groups for integration 1.
# 2020-02-24 18:06:36,837 - INFO - Simulating 80 groups for integration 2.
# 2020-02-24 18:06:55,938 - INFO - Simulating 80 groups for integration 3.
# 2020-02-24 18:07:15,020 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2020-02-24 18:07:18,549 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits
# 2020-02-24 18:07:32,695 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-24 18:07:48,051 - INFO - Wrote detector image: 20200224_175716_mirisim/det_images/det_image_seq1_MIRIFULONG_34LONGexp1.fits
# 2020-02-24 18:07:48,058 - INFO - MIRI Simulation finished. Results have been saved to: 20200224_175716_mirisim

# %% [markdown]
# ## Examine some of the results
#
# Outputs are in a date-labelled directory taking the form  <code>YYYYMMDD_hhmmss_mirisim</code>.  The name of the output directory is given in the last line of the MIRISim log above.  Because the output directory is date-labelled, we can quantify which was the most recent run of MIRISim, and find its output directory using <code>glob.glob</code>

# %% [markdown]
# ### The results of the MRS simulation for the 5-28 micron range are contained in three directories - one for each disperser

# %%
directory_list = sorted(glob.glob('*_*_mirisim'),key=os.path.getmtime)[-3:] # Takes the last three entry found

# %%
for num, outputdir in enumerate(directory_list):
    outputDirContents = os.listdir(outputdir)
    
    directories = [name for name in outputDirContents if os.path.isdir(os.path.join(outputdir,name))]
    files = [name for name in outputDirContents if not os.path.isdir(os.path.join(outputdir,name))]

    print('\nFor the {} the output directory is: {} '.format(sim_filenames[num], outputdir))
    print('The subdirectories in the {} directory are:\n{}'.format(outputdir,directories))
    print('The files in the output directory are:\n{}'.format(files))
# Out:
# For the MRS_short_SN1987A_simulation the output directory is: 20200224_173502_mirisim
# The subdirectories in the 20200224_173502_mirisim directory are:
# ['det_images', 'illum_models', 'skycubes']
# The files in the output directory are:
# ['mirisim.log', 'scene.ini', 'simulation.ini', 'simulator.ini']
#
# For the MRS_medium_SN1987A_simulation the output directory is: 20200224_174622_mirisim
# The subdirectories in the 20200224_174622_mirisim directory are:
# ['det_images', 'illum_models', 'skycubes']
# The files in the output directory are:
# ['mirisim.log', 'scene.ini', 'simulation.ini', 'simulator.ini']
#
# For the MRS_long_SN1987A_simulation the output directory is: 20200224_175716_mirisim
# The subdirectories in the 20200224_175716_mirisim directory are:
# ['det_images', 'illum_models', 'skycubes']
# The files in the output directory are:
# ['mirisim.log', 'scene.ini', 'simulation.ini', 'simulator.ini']

# %% [markdown]
# The files contain the log which was also output to the terminal (<code>mirisim.log</code>) and the .ini files used to create the simulation. These versions of the .ini files can be used to re-create the run of the simulation.
#
# The directories contain various outputs of MIRISim:
#
# * **<code> skycubes </code>** houses a 3D representation of the input scene to the MRS simulation (skycubes are not generated for imager or LRS simulations). This cube has not been processed by MIRISim, it is simply a gridded (spatially and spectrally) version of the input scene.
# * **<code> illum_models </code>** houses FITS images of the illuminations sent to the detector (sent to SCAsim - the simulator of the Sensor Chip Assembly).  This should have the same format as the detector image, but without all of the detector effects and noise. There are FITS files produced for each exposure and dither position
# * **<code> det_images </code>** houses FITS images of the final outputs of MIRISim. These detector images have all of the detector effects and noise incorporated. The number of detector images should be the same as the number of illumination models.
#
# The headers of the detector images are formatted for ingest into the JWST pipeline.

# %% [markdown]
# ### Viewing a slice of the skycube
#
# Below, we show an image of the central channel of one of the skycubes generated by MIRISim.
#
# NOTE: The symmetric ring generated in the scene may appear as an ellipse in the sky cube slice. This is due to the aspect ratio and automatic axis functionality in matplotlib.

# %%
show_outputs(directory_list[2],'skycubes')

# %% [markdown]
# ### Viewing an averaged spectrum over the full MRS FOV for each disperser and channel of the input scene to the MRS simulation
#
# For the full MRS spectral range a total of **12** **<code>skycubes</code>** are generated by MIRISim- four per disperser. NOTE: These cubes have not been processed by MIRISim.
# Below, we show an average spectum for the input scene across the MRS FOV for each of the 12 **<code>skycubes</code>**. The wavelength ranges of each skycube is also printed.
#
# NOTE: The fluxes are not normalised between each indivisual plot.

# %%
show_skycubes_spec(directory_list)

# %% [markdown]
# ## Viewing the final detector image
#
# The detector images are the final output of MIRISim, and have data structures and formatting consistent with what will come from MIRI itself. The data format is JWST pipeline ready.  Below an example image of the last frame of the last integration is shown. The units are <code>DN</code>.

# %%
### Loop for all simulations  - SML for 1/2 and 3/4 
for outputdir in directory_list:
    filenames_det_images = glob.glob('{}/{}/*.fits'.format(outputdir,'det_images')) # Get skycube file
    
    for det_images_file in filenames_det_images:
        
        hdulist = fits.open(det_images_file) # Open file 

        hdu_index = 1
        if len(hdulist[hdu_index].data.shape) > 2:
            integ,frames,nx,ny = hdulist[hdu_index].data.shape
            image = hdulist[hdu_index].data[integ-1,frames-1,:,:]
        else:
            image = hdulist[hdu_index].data

        plt.imshow(image, origin = 'lower',cmap = cm.viridis,interpolation='nearest')
        plt.title('{}'.format(det_images_file.split('/')[-1]))
        plt.xlabel('Along Slice Direction')
        plt.ylabel('Wavelength Direction')
        plt.show()
        plt.close()

# %% [markdown]
# ## The outputs of MIRISim can now be run through the JWST pipeline see:
# ###  https://jwst-docs.stsci.edu/jwst-data-reduction-pipeline and https://jwst-pipeline.readthedocs.io/en/stable/
