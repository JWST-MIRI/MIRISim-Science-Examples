# %% [markdown]
# #  SN1987A:  MIRISim (MRS IFU)
#
# #### This notebook replicates the MIRI MRS IFU spectroscopy part of the SN 1987A: The Formation and Evolution of Dust in a Supernova Explosion JWST GTO programme (#1232).
#
# Details of generating ETC and APT files in this example science program can be found on the JDoX webpages: https://jwst-docs.stsci.edu/mid-infrared-instrument/miri-example-science-programs/miri-mrs-and-nirspec-ifu-observations-of-sn1987a
#
# **Science Objective:**
# The main science goals of this project are to understand how massive stars age and explode, how their ejecta form dust and molecules, and how the blast wave from their violent explosion affects their surroundings. JWST MIRI imaging, and medium resolution spectroscopy (MRS) will provide key emission line diagnostics and dust feature and continuum measurements of SN 1987A. The central stellar ejecta of SN 1987A is surrounded by a ring of progenitor gas and dust that is being shocked by the blast wave of the explosion. A large quantity (0.4–0.7 solar masses; Matsuura et al. 2011) of dust in the stellar ejecta has an unknown composition, and these observations may provide the first constraints through imaging and spatially resolved spectroscopy.  The **MRS IFU** spectroscopy will measure key shocked line diagnostics that will further constrain the shock physics as well as the elemental abundances in both the ring and the stellar ejecta.
#
# **In this notebook**, we create a scene with a cold blackbody ~ 20K replicating the inner ejecta of SN 1987A and a ring of warm (~ 100K) silicate dust and atomic emission lines surrounding the ejecta that all fit within the MRS field of view, and run through a MIRISim simulation showing the products created at each stage.
#
# **NOTE** this notebook must be started within  the correct anaconda environment in which you have MIRISim installed. This is a prerequisite for using MIRISim, and installation instructions can be found [here](http://miri.ster.kuleuven.be/bin/view/Public/MiricleInstallation).
#
# When launching the notebook, make sure in the right Anaconda environment. i.e. type
#
#
# <code> source activate miricle </code>
#
# in the terminal before starting the notebook.
#
# ### Steps in this notebook:
#
# 0. Import useful python packages
# 1. Create a Scene
# 2. Initialise the simulation parameters
# 3. Run the simulation
# 4. Examine some of the outputs.

# %% [markdown]
# ## Step 0 - Some general python housekeeping
# ### Import useful python packages

# %%
# Import usefull python packages
import numpy as np
import glob                 # glob is used to find the output directory
import os                   # for listing directory contents
from astropy.io import fits # for reading FITS file contents

# Import python packages used to display images inline in the notebook
import matplotlib.pyplot as plt    
from matplotlib import colors,cm
# %matplotlib inline       

######################################
# Now import MIRISim specific packages 

# import the configuration file parsers so they can be written to file
from mirisim.config_parser import SimConfig, SimulatorConfig, SceneConfig

# import scene component generators
from mirisim.skysim import Background, sed, Point, Galaxy, kinetics, ExternalSed
from mirisim.skysim import wrap_pysynphot as wS

from mirisim import MiriSimulation
# Out:
# WARNING: AstropyDeprecationWarning: astropy.extern.six will be removed in 4.0, use the six module directly if it is still needed [astropy.extern.six]

# %% [markdown]
# ### Define some common functions
#
# 1) <code>save_to_fits</code> - Used to save the generated scene to a fits file
#
# 2) <code>show_outputs</code> - Used in plotting outputs from MIRISim
#
# 3) <code>row_based_idx</code> - Used to fill matplotlib subplots by column, not row
#
# 4) <code>show_skycubes_spec</code> - Used to plot the spectrum in datacubes generated by MIRISim

# %%
def save_to_fits(scene, light_path, filename='MIRISim_scene.fits', SpatialSampling=0.1, WavelengthRange=None, 
                 WavelengthSampling=0.1):
    """
    Function to save the MIRISim scene to a fits file.
    
    :param filename: Name of file to save - default is "MIRISim_scene.fits"
    :type filename: string       
    
    :param SpatialSampling: Spatial sampling (in arcsec) - default is 0.1 arcseconds
    :type SpatialSampling: float
    
    :param WavelengthRange: Wavelength range to process (in microns) - default is [5, 28] microns
    :type WavelengthRange: array
    
    :param WavelengthSampling: Channel width (in microns) - default is 0.1 arcseconds
    :type WavelengthSampling: float
    
    :rtype: None
    :raises Exception: when light_path parameter not set to MRS or IMA
    """
    
    # Avoids array being extended inside function for mutliple calls. Python gotcha
    if WavelengthRange is None:
        WavelengthRange = [5, 28]
        
    if light_path == 'IMA':
        # IMA Field of view [xmin,xmax],[ymin,ymax] [arcsec]
        FOV = np.array([[-57., 57.],[-57., 57.]])   
    elif light_path == "MRS":
        # MRS Field of view [xmin,xmax],[ymin,ymax] [arcsec]
        FOV = np.array([[-4., 4.],[-4., 4.]])       
    else:
        raise Exception('Acceptable inputs for parameter light_path are [IMA] and [MRS]')
    
    # overwrite = True enables overwriting of any previous version of the fits file
    # with the same name as that given in the writecube command
    scene.writecube(cubefits = filename,
                    FOV = FOV, time = 0.0,
                    spatsampling = SpatialSampling,
                    wrange = WavelengthRange,
                    wsampling = WavelengthSampling,
                    overwrite = True)

# %%
def show_outputs(MIRISim_outputdir,output_type):
    """
    Plot the specified channel of the MIRISim outputs
    :param MIRISim_outputdir:  
        name of the date-labelled dir. holding the MIRISIM outputs
    :param output_type: 
        type of output to process 
        (e.g. illum_models, det_images or skycubes)
    """
    
    infits = glob.glob('{}/{}/*.fits'.format(MIRISim_outputdir,output_type))[0]
    
    hdulist = fits.open(infits)
    
    if output_type.lower() == 'skycubes': 
        hdu_index = 0
        datashape = hdulist[hdu_index].data.shape
        central_chan = datashape[0]//2
        
        plt.imshow(hdulist[hdu_index].data[central_chan,:,:],
           origin = 'lower', interpolation = 'nearest',cmap = cm.viridis, aspect='equal')
        plt.title('channel {} of {}'.format(central_chan,infits.split('/')[-1]))
        plt.xlabel(hdulist[hdu_index].header['ctype1'])
        plt.ylabel(hdulist[hdu_index].header['ctype2'])
    else:
        hdu_index = 1
        if len(hdulist[hdu_index].data.shape) > 2:
            integ,frames,nx,ny = hdulist[hdu_index].data.shape
            image = hdulist[hdu_index].data[integ-1,frames-1,:,:]
        else:
            image = hdulist[hdu_index].data
            
        
        plt.imshow(image, origin = 'lower',cmap = cm.viridis,interpolation='nearest', aspect='equal')
        plt.title('{}'.format(infits.split('/')[-1]))
        plt.xlabel('Along Slice Direction')
        plt.ylabel('Wavelength Direction')

    plt.colorbar()

# %%
def row_based_idx(num_rows, num_cols, idx):
    """
    Function to fill matplotlib subplots by column, not row
    """
    return np.arange(1, num_rows*num_cols + 1).reshape((num_rows, num_cols)).transpose().flatten()[idx-1]

# %%
def show_skycubes_spec(directory_list):
    """
    Plots the average MIRISim spectra for each FOV from the 12 skycubes generated from 
    the Short, Medium and Long dispersers
    :param directory_list:  
        List contaning the three output directories for the MRS simulation results
    """    
    
    # Define subplot grid for the MRS skycubes
    num_cols = 3 
    num_rows = 4             

    maxfigs = 12
    fig = plt.figure(figsize=(10,3*num_rows))
    i=0

    for num, outputdir in enumerate(directory_list):
        outputDirContents = os.listdir(outputdir)

        directories = [name for name in outputDirContents if os.path.isdir(os.path.join(outputdir,name))]

        #print('\nFor the {} the output directory is: {} '.format(sim_filenames[num], outputdir))
        #print('This directory contains four skycubes which cover the wavelength ranges:')

        filenames_skycube = glob.glob('{}/{}/*.fits'.format(outputdir,'skycubes')) # Get skycube file

        for skycube_file in filenames_skycube:

            hdu = fits.open(skycube_file)        # Open file 
            data_cube = hdu[0].data              # Get data 
            #datashape = hdu[0].data.shape       # Get data shape - Z, X, Y  

            # Get the wavelength data 
            wav =  hdu[1].data

            # Find the max and min wavelelgths for the output cube
            vmin = wav[0]
            vmax = wav[-1]       
            #print(np.round(vmin,2), np.round(vmax,2))

            # Get the flux data from an average of the cube
            spectrum = data_cube.mean(axis=(1, 2))  

            # Plot the spectrum - Each colum = short, medium, long
            plt.subplot(num_rows, num_cols, row_based_idx(num_rows, num_cols,i+1))
            plt.plot(wav, spectrum)                                       
            #plt.xticks([])  # help clean up the plot
            plt.yticks([])   # help clean up the plot 
            i+=1    

    fig.add_subplot(111, frame_on=False)

    plt.tick_params(labelcolor="none", bottom=False, left=False)
    plt.xlabel("Wavelength (microns)", fontsize=14)
    plt.ylabel("Flux (data units)", fontsize=14)

    fig.suptitle('    Short                           Medium                           Long', y=1.02, fontsize=18)

    fig.tight_layout()

    plt.show()
    plt.close()

# %% [markdown]
# ### Set flags for saving the MIRISim scene to a fits file - default is False
# We select false as the default as 1) a fits file of the scene is not necessary to run mirisim; 2) this step can take a long time to run; 3) once a scene has been saved as a fits file one this step is not necessary.

# %%
save_scene_as_fits = False

# %% [markdown]
# ## Step 1 - Create a Scene - this represents your science observation
#
# Each scene should include at minimum: 1) A background level; 2) A science source
#
# The scene created below consists of a cold ~ 20K blackbody replicating the inner ejecta of SN1987A and a ring of warm silicate dust surrounding the ejecta that all of which fit within the MRS field of view. The first point source has a 20 K blackbody SED, the ring has a SED imported from Spitzer IRS observations.

# %% [markdown]
# #### Create a low level background for the scene

# %%
bg = Background(level='low',gradient=9., pa=45.)
# Out:
# 2020-02-25 13:50:51,106 - INFO - Initializing Background

# %% [markdown]
# #### Create the First Point Source - replicating the cold (~20 K) dust in the inner ejecta - Flux values and tempratures from Matsuura et al. 2011

# %%
# Initialise a single point source at the central position of the MIRI MRS
"""
MIRI MRS FOV     = 3.7 × 3.7  arcseconds  in ALL four channels 
Max MIRI MRS FOV = 7.2 × 7.9  arcseconds  
"""
point1 = Point(Cen = (0.0,0.0))

# Set properties of the SED for point 1
Blackbody = sed.BBSed(Temp = 26., wref = 20., flux = 45.4 * 1000)  # Temp = K, wref = microns, flux = micro Jy 

# Add the SED to the point source
point1.set_SED(Blackbody)

# Add ejecta (point1) to the compound target list called 'sn1987A_components' for creating a scene
sn1987A_components = point1

# For writing to scene.ini file
targetlist = [point1]
# Out:
# 2020-02-25 13:50:51,114 - INFO - Initializing Point

# %% [markdown]
# ### Create the ring surrounding the ejecta
#
# #### 1) First import the SED from an external file

# %%
# Get SEDs of the ring for SN1987A observed with Spitzer IRS. Data from Jones et al. 2017b 

# Use: sedfile =  ExternalSed('extsed.txt') # filepath, columns 'wavelength' [microns] and 'flux' [muJy]
ring_sed = ExternalSed(sedfile = 'SN1987A_ring_microJy.txt') 

# For zooming in on spectral ranges
l_min = 5 #micron
l_max = 28 #micron
sp_min = np.abs(ring_sed.Lam-l_min).argmin()
sp_max = np.abs(ring_sed.Lam-l_max).argmin()

# Plot the Spitzer spectrum of the SN1987A ring component for refrence
fig = plt.figure(figsize=(8, 6))
ax = plt.subplots()[1]  
ax.plot(ring_sed.Lam[sp_min:sp_max], ring_sed.fLam[sp_min:sp_max])   
ax.set_xlabel("Wavelength (microns)")  
ax.set_ylabel("Flux (mJy)")  
ax.set_title("External SED of SN1987A ring")  
plt.close(fig)

# %% [markdown]
# #### 2) Then attach the SED to an object

# %%
# Set up the spatial distibution of the ring of SN1987A

# Create a ring of sources and add them to the scene
MRS_radius = 3.2/2.   # Radius of MRS (in arcsec)             
Nring = 16            # Number of ring components to put within the MRS 

# Create a circle of resolved objects to replicate the ring, add the SED to each object and add to the scene
for i in range(0,Nring):
      
    xp = np.cos(2*np.pi/Nring*i)*MRS_radius
    yp = np.sin(2*np.pi/Nring*i)*MRS_radius
    
    # Initlise a ring using the galaxy template of a non-pointsource 
    ring = Galaxy(Cen = (xp,yp),n=0.5,re=0.15,q=0.33,pa=360/Nring*i)  # n = sersic idx; re = eff. rad. [arcsec] ; q = axis ratio
 
    # Add the Spitzer IRS observtions of the ring from Jones et al 2017b to generate the SED of initialised ring
    ring.set_SED(ring_sed)

    sn1987A_components += ring    # For creating a scene
    targetlist.append(ring)       # For writing to scene.ini file
# Out:
# 2020-02-25 13:50:51,359 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,360 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,362 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,363 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,363 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,364 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,365 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,365 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,366 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,366 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,368 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,368 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,369 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,369 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,370 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,370 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,371 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,373 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,374 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,375 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,375 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,376 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,378 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,378 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,379 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,379 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,380 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,383 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,384 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,385 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,386 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,386 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,387 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,388 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,389 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,389 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,390 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,391 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,394 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,394 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,395 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,396 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,397 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,399 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,399 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,400 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,401 - INFO - Initializing Galaxy
# 2020-02-25 13:50:51,403 - INFO - Initializing Galaxy

# %% [markdown]
# ### From the components, create a scene
#
# To create a scene adding together the background and targets i.e the ejecta component and the ring components.

# %%
scene = bg +  sn1987A_components

# %% [markdown]
# ### Export the scene to an ini file and FITS file (optional)
#
# Export scene to an ini file (for future use), or a FITS file to be visualised. This stage is not necessary if runing mirisim in a notebook.
#
# Exporting to a FITS file requires specifing a number of aditional parametrs such as the Field of view, required spectral sampling, etc. They're described in more detail below. For large fields of view, and/or small spectral channels, which create large FITS files, writing to a FITS file can take a while (few minutes)

# %%
# Used to run MIRISim within notebook
scene_config = SceneConfig.makeScene(loglevel=0,
                                    background=bg,
                                    targets = targetlist)

# Export to ini file - not necessary if runing mirisim in notebook
os.system('rm -fr MRS_SN1987A_scene.ini')      # Remove previous version of .ini file
scene_config.write('MRS_SN1987A_scene.ini')

# %% [markdown]
# ##### OPTIONAL - Save the generted scene to a fits file - Note this step can take a long time depening on the chosen perameters

# %%
# Export to FITS file - Optional 
if save_scene_as_fits == True:
    save_to_fits(scene, light_path="MRS", filename='MIRISim_scene.fits')

# %% [markdown]
# ## Initialise the MRS Simulation Parameters
#
# This is where the parameters for the MRS simulation get set.  These should be set to match the desired MIRI observation setup.
#
# **Note** MIRISim must have perameters set for all light paths in <code>SimConfig.makeSim</code> this includes some perameters not relevent to the MRS simulation defined in this file. Those perameters not being used in this simulation are labelled with <code> NOT USED HERE </code> in the comments of each line **and should not be deleted**.
#
# ### SN1987A MRS obsevation set up:
#
# For SN 1987A we want to simulate a spectrum covering the full MRS 5-28 micron wavelength range.  To replicate this in MIRISim - **3 simulations are needed to obtain a full spectrum** using SHORT MEDIUM and LONG respectively using both the short and long wavelength arms (CH 1 & 2 and CH 3 & 4 respectively).
#
# 1. Dither = Extended source 4pt
# 2. Read out mode = <code>FAST</code> selected based on best practices.
#
# #### Desperser  -   Groups - Integrations
# - Short:  80 groups and 3 integrations
# - Medium: 80 groups and 3 integrations
# - Long:   80 groups and 3 integrations
#
# NB A <code>FAST</code> readout pattern selected due to high dynamic range in flux for the ring and the ejecta. This will prevent sauturaion.

# %% [markdown]
# ###  To get the full 5-28 micron spectral range this simulation uses all three despersers.
#
# #### In the MRS observation set up select appropriate values for the three despersers to loop the simulation over.
#
# The following setup assumes that the user is using the full MRS spectral range.
# Parameters to be adjusted based on your desired observation setup are the:
#
# * sim_filenames
# * mrs_exposure_values
# * mrs_integration_values
# * mrs_frame_values

# %%
# Generate a list of three config names for the simulations 
sim_config_list = ['sim_config_s', 'sim_config_m','sim_config_l']

# Set the file names of the three simulations
sim_filenames = ['MRS_short_SN1987A_simulation', 'MRS_medium_SN1987A_simulation', 'MRS_long_SN1987A_simulation']

# Configure the Optical path (MRS sub-band)  
config_path_list = ['MRS_1SHORT', 'MRS_1MEDIUM', 'MRS_1LONG']

# Which disperser to use (SHORT/MEDIUM/LONG) 
disperser_list = ['SHORT', 'MEDIUM', 'LONG']

# Number of MRS exposures 
mrs_exposure_values = [1,1,1]

# Number of MRS integrations
mrs_integration_values = [3,3,3]

# Number of groups (for MIRI, # Groups = # Frames)
mrs_frame_values = [80, 80, 80]

# %%
# Now to loop through the three desperser simulation setups 

# Generate combined list of the observation perameters for the three dispersers 
# based on the values imput in the previous cell.
observaton_setup = [
    sim_filenames, config_path_list, disperser_list,
    mrs_exposure_values, mrs_integration_values, mrs_frame_values]

print("SimConfig populated by:")

# Builds a list to contain the sim_obects built in the below loop
sim_objects = list()

# Generates the three simulation objects for the short medium and long and populates 
# the sim_objects list
# Use python zip function to index arrays to minimise potential errors by passing 
# arguments of unequal length 
for (sim_name_el, config_path_list_el, disperser_list_el, 
     mrs_exposer_value_el, mrs_integration_value_el, mrs_frame_values_el) in zip(*observaton_setup):
    
    print ("{} : {} : {} : {} : {} : {}".format(sim_name_el, config_path_list_el,
                                                     disperser_list_el, mrs_exposer_value_el, 
                                                     mrs_integration_value_el, mrs_frame_values_el))
    
    # Add a safety check to make sure each parameter contains values for all the disperser settings. 
    if (len(sim_config_list) != len(sim_filenames) != len(config_path_list) != len(disperser_list) 
        != len(mrs_exposure_values) != len(mrs_integration_values) != len(mrs_frame_values)):
        raise Exception("All three values are not set - Check imputs.")
    
    ############################################################################################
    # This sets up the simulation - adjust values spefific to your observation setup you wish to simulate 
    
    sim_objects.append(SimConfig.makeSim(
        name = sim_name_el,                   # Name given to simulation
        scene = 'MRS_SN1987A_scene.ini',      # Name of scene file to input

        rel_obsdate = 0.0,                    # Relative observation date (0 = launch, 1 = end of 5 yrs)
        POP = 'MRS',                          # Component on which to center (IMA or MRS)
        ConfigPath = config_path_list_el,     # Configure the Optical path (MRS sub-band)

        disperser = disperser_list_el,        # Which disperser to use (SHORT/MEDIUM/LONG)
        detector = 'BOTH',                    # Specify Channel (SW = channels 1,2, LW= channels 3,4, or BOTH)
        mrs_mode = 'FAST',                             # MRS read mode (default is Fast)
        mrs_exposures = mrs_exposer_value_el,          # Number of exposures
        mrs_integrations = mrs_integration_value_el,   # Number of integrations
        mrs_frames = mrs_frame_values_el,              # Number of groups (for MIRI, # Groups = # Frames)

        ############################################################################################
        # This is where you set up your dither parameters - adjust values spefific to your observation 
        
        Dither = False,             # Don't Dither    
        StartInd = 1,               # Start index for dither pattern 
        NDither = 4,                # Number of dither positions 
        DitherPat = 'mrs_recommended_dither.dat', # Dither pattern to use 
        
        
        ############################################################################################
        # These parameters are not used in the MRS simulation and should not be adjusted (or deleted)
        ima_exposures = 0,           # [NOT USED HERE]
        ima_integrations = 16,       # [NOT USED HERE]
        ima_frames = 14,             # [NOT USED HERE]
        ima_mode = 'FAST',           # [NOT USED HERE]
        filter = 'F1000W',           # [NOT USED HERE]
        readDetect = 'BRIGHTSKY'     # [NOT USED HERE]
        ))
# Out:
# SimConfig populated by:
# MRS_short_SN1987A_simulation : MRS_1SHORT : SHORT : 1 : 3 : 80
# MRS_medium_SN1987A_simulation : MRS_1MEDIUM : MEDIUM : 1 : 3 : 80
# MRS_long_SN1987A_simulation : MRS_1LONG : LONG : 1 : 3 : 80

# %% [markdown]
# ### Export the simulation setup files
#
# Not necessary as saved in mirisim output in the date stamped output directory. Included here as naming each file explicitly for record keeping.

# %%
for sim_object, file_name in zip(sim_objects, sim_filenames):
    os.system('rm {}.ini'.format(file_name))
    sim_object.write("{}.ini".format(file_name))

# %% [markdown]
# ## Run the simulation
#
# Now that the scene and the setup of the simulation have been set, we can run the simulation.
# The last step is to setup the defaults for internal things like CDPs.

# %%
# Get the simulation configuration perameters using the default setup
simulator_config = SimulatorConfig.from_default()

# %%
for sim_object in sim_objects:
    mysim = MiriSimulation(sim_object,scene_config,simulator_config)
    mysim.run()
# Out:
# 2020-02-25 13:50:51,504 - INFO - MIRISim version: 2.2.0dev0
# 2020-02-25 13:50:51,506 - INFO - MIRI Simulation started.
# 2020-02-25 13:50:51,506 - INFO - Output will be saved to: 20200225_135051_mirisim
# 2020-02-25 13:50:51,508 - INFO - Storing configs in output directory.
# 2020-02-25 13:50:55,030 - INFO - Using $CDP_DIR for location of CDP files: //Users/ojones/Data/MIRI_testing
# 2020-02-25 13:50:55,766 - INFO - Reading cosmic ray properties from parameter file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/scasim/cosmic_ray_properties.py
# 2020-02-25 13:50:55,826 - INFO - Reading detector properties from parameter file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/scasim/detector_properties.py
# 2020-02-25 13:50:56,096 - INFO - Setting up simulated Observation, with following settings:
# 2020-02-25 13:50:56,098 - INFO - Configuration Path: MRS_1SHORT
# 2020-02-25 13:50:56,098 - INFO - Primary optical path: MRS
# 2020-02-25 13:50:56,099 - INFO - MRS detector: BOTH
# 2020-02-25 13:50:56,100 - INFO - MRS band: SHORT
# 2020-02-25 13:50:56,101 - INFO - MRS detector readout mode: FAST
# 2020-02-25 13:50:56,102 - INFO - MRS detector # exposures: 1
# 2020-02-25 13:50:56,103 - INFO - MRS detector # integrations: 3
# 2020-02-25 13:50:56,104 - INFO - MRS detector # frames: 80
# 2020-02-25 13:50:56,105 - INFO - Parsing: Background
# 2020-02-25 13:50:56,106 - INFO - Initializing Background
# 2020-02-25 13:50:56,107 - INFO - Parsing: point_1
# 2020-02-25 13:50:56,107 - INFO - Initializing Point
# 2020-02-25 13:50:56,109 - INFO - Parsing: galaxy_1
# 2020-02-25 13:50:56,109 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,110 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,111 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,138 - INFO - Parsing: galaxy_2
# 2020-02-25 13:50:56,139 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,140 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,141 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,169 - INFO - Parsing: galaxy_3
# 2020-02-25 13:50:56,170 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,172 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,173 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,198 - INFO - Parsing: galaxy_4
# 2020-02-25 13:50:56,199 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,200 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,201 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,230 - INFO - Parsing: galaxy_5
# 2020-02-25 13:50:56,231 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,232 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,232 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,259 - INFO - Parsing: galaxy_6
# 2020-02-25 13:50:56,261 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,262 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,263 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,289 - INFO - Parsing: galaxy_7
# 2020-02-25 13:50:56,290 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,291 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,292 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,318 - INFO - Parsing: galaxy_8
# 2020-02-25 13:50:56,319 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,320 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,320 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,345 - INFO - Parsing: galaxy_9
# 2020-02-25 13:50:56,346 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,347 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,348 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,376 - INFO - Parsing: galaxy_10
# 2020-02-25 13:50:56,377 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,378 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,379 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,407 - INFO - Parsing: galaxy_11
# 2020-02-25 13:50:56,408 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,409 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,409 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,439 - INFO - Parsing: galaxy_12
# 2020-02-25 13:50:56,440 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,441 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,442 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,471 - INFO - Parsing: galaxy_13
# 2020-02-25 13:50:56,473 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,474 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,475 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,504 - INFO - Parsing: galaxy_14
# 2020-02-25 13:50:56,506 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,507 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,508 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,536 - INFO - Parsing: galaxy_15
# 2020-02-25 13:50:56,538 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,540 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,541 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,569 - INFO - Parsing: galaxy_16
# 2020-02-25 13:50:56,570 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,572 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,574 - INFO - Initializing Galaxy
# 2020-02-25 13:50:56,606 - INFO - Simulating a single pointing.
# 2020-02-25 13:51:00,058 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02
- INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-25 13:55:04,222 - INFO - Valid cache found.
# 2020-02-25 13:55:04,225 - INFO - Starting Coordinate Transformation
# 2020-02-25 13:55:17,289 - INFO - Starting pixel projection with cache.
# 2020-02-25 13:56:52,136 - INFO - Mapping completed
# 2020-02-25 13:56:52,137 - INFO - Detector Intensity Array completed.
# 2020-02-25 13:56:52,611 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_FRINGE_07.02.05.fits'
# 2020-02-25 13:56:52,744 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_PHOTOM_07.03.00.fits'
# 2020-02-25 13:56:52,857 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 13:56:52,896 - INFO - MRS light path simulation finished.
# 2020-02-25 13:56:52,946 - INFO - Added 1 Cube to output list
# 2020-02-25 13:56:52,947 - INFO - Added 2 Cube to output list
# 2020-02-25 13:56:53,049 - INFO - Starting pySpecSimMiri
# 2020-02-25 13:56:53,061 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-25 13:56:53,061 - INFO - Instrument setup starting.
# 2020-02-25 13:56:53,063 - INFO - Detector setup starting.
# 2020-02-25 13:56:53,064 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-25 13:56:53,066 - INFO - MRS light path simulation starting.
# 2020-02-25 13:56:53,067 - INFO - Simulating Instrument.
# 2020-02-25 13:56:53,079 - INFO - Simulating Detector.
# 2020-02-25 13:56:53,080 - INFO - Simulating Detector Mapping for channel ['3'] and band SHORT
# 2020-02-25 13:56:53,081 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 13:56:53,084 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-25 13:56:53,530 - INFO - Valid cache found.
# 2020-02-25 13:56:53,532 - INFO - Starting Coordinate Transformation
# 2020-02-25 13:57:05,552 - INFO - Starting pixel projection with cache.
# 2020-02-25 13:58:32,800 - INFO - Mapping completed
# 2020-02-25 13:58:32,801 - INFO - Detector Intensity Array completed.
# 2020-02-25 13:58:33,242 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_FRINGE_07.02.00.fits'
# 2020-02-25 13:58:33,430 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_PHOTOM_07.03.00.fits'
# 2020-02-25 13:58:33,560 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 13:58:33,627 - INFO - Simulating Detector Mapping for channel ['4'] and band SHORT
# 2020-02-25 13:58:33,628 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 13:58:33,630 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2020-02-25 13:58:34,129 - INFO - Valid cache found.
# 2020-02-25 13:58:34,131 - INFO - Starting Coordinate Transformation
# 2020-02-25 13:58:42,516 - INFO - Starting pixel projection with cache.
# 2020-02-25 13:59:42,963 - INFO - Mapping completed
# 2020-02-25 13:59:42,964 - INFO - Detector Intensity Array completed.
# 2020-02-25 13:59:43,420 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_FRINGE_07.02.00.fits'
# 2020-02-25 13:59:43,564 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_PHOTOM_07.03.00.fits'
# 2020-02-25 13:59:43,677 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 13:59:43,710 - INFO - MRS light path simulation finished.
# 2020-02-25 13:59:43,719 - INFO - Added 3 Cube to output list
# 2020-02-25 13:59:43,720 - INFO - Added 4 Cube to output list
# 2020-02-25 13:59:43,918 - INFO - Wrote illumination model: 20200225_135051_mirisim/illum_models/illum_model_seq1_MIRIFUSHORT_12SHORT.fits
# 2020-02-25 13:59:43,969 - INFO - Wrote illumination model: 20200225_135051_mirisim/illum_models/illum_model_seq1_MIRIFULONG_34SHORT.fits
# 2020-02-25 13:59:43,970 - INFO - Simulating integrated detector images for MRS exposures for pointing 1
# 2020-02-25 13:59:43,971 - INFO - Simulating MRS exposure 1
# 2020-02-25 13:59:43,975 - INFO - Running SCASim
# 2020-02-25 13:59:43,975 - INFO - Simulating  detector readout for MIRIFUSHORT from illumination data model of shape (1024, 1024).
# 2020-02-25 13:59:43,989 - INFO - Results will be returned in an exposure data model.
# 2020-02-25 13:59:44,009 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-25 13:59:44,010 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-25 13:59:44,011 - INFO -   Detector subarray mode is FULL.
# 2020-02-25 13:59:44,012 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-25 13:59:44,013 - INFO - Cosmic ray environment is SOLAR_MIN.
# 2020-02-25 13:59:44,014 - INFO - Reading cosmic ray library file: '/Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/data/cosmic_rays/CRs_SiAs_470_SUNMIN_08.fits'
# 2020-02-25 13:59:44,068 - INFO - Simulation control flags:
# 2020-02-25 13:59:44,069 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-25 13:59:44,070 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-25 13:59:44,071 - INFO - 	Read noise simulation turned ON.
# 2020-02-25 13:59:44,071 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-25 13:59:44,072 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-25 13:59:44,073 - INFO - 	Dark current simulation turned ON.
# 2020-02-25 13:59:44,075 - INFO - 	Flat-field simulation turned ON.
# 2020-02-25 13:59:44,075 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-25 13:59:44,076 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-25 13:59:44,077 - INFO - 	Detector drift effects turned ON.
# 2020-02-25 13:59:44,078 - INFO - 	Detector latency effects turned ON.
# 2020-02-25 13:59:44,081 - INFO - Creating a new detector object for 1024 rows x 1024 columns.
# 2020-02-25 13:59:44,090 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_MASK_07.02.01.fits'
# 2020-02-25 13:59:44,181 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 13:59:48,229 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits'
# 2020-02-25 13:59:48,413 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12SHORT_FLAT_8B.01.00.fits'
# 2020-02-25 13:59:48,573 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFUSHORT with FAST mode with band='SHORT'. An alternative is being used.
# 2020-02-25 13:59:48,603 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits'
# 2020-02-25 13:59:48,858 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_READNOISE_07.01.00.fits'
# 2020-02-25 13:59:48,930 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-25 13:59:49,038 - INFO - Simulating 3 integrations.
# 2020-02-25 13:59:49,046 - WARNING - ***Input flux array contains 1 negative values.
# 2020-02-25 13:59:49,116 - INFO - Simulating 80 groups for integration 1.
# 2020-02-25 14:00:10,128 - INFO - Simulating 80 groups for integration 2.
# 2020-02-25 14:00:31,003 - INFO - Simulating 80 groups for integration 3.
# 2020-02-25 14:00:51,885 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits
# 2020-02-25 14:00:55,876 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits
# 2020-02-25 14:01:16,163 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-25 14:01:32,469 - INFO - Wrote detector image: 20200225_135051_mirisim/det_images/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits
# 2020-02-25 14:01:32,470 - INFO - Simulating MRS exposure 1
# 2020-02-25 14:01:32,474 - INFO - Running SCASim
# 2020-02-25 14:01:32,476 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2020-02-25 14:01:32,489 - INFO - Results will be returned in an exposure data model.
# 2020-02-25 14:01:32,506 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-25 14:01:32,507 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-25 14:01:32,508 - INFO -   Detector subarray mode is FULL.
# 2020-02-25 14:01:32,509 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-25 14:01:32,510 - INFO - Cosmic ray environment is SOLAR_MIN.
# 2020-02-25 14:01:32,511 - INFO - Reading cosmic ray library file: '/Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/miri/simulators/data/cosmic_rays/CRs_SiAs_470_SUNMIN_02.fits'
# 2020-02-25 14:01:32,591 - INFO - Simulation control flags:
# 2020-02-25 14:01:32,593 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-25 14:01:32,593 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-25 14:01:32,594 - INFO - 	Read noise simulation turned ON.
# 2020-02-25 14:01:32,595 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-25 14:01:32,596 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-25 14:01:32,597 - INFO - 	Dark current simulation turned ON.
# 2020-02-25 14:01:32,598 - INFO - 	Flat-field simulation turned ON.
# 2020-02-25 14:01:32,598 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-25 14:01:32,599 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-25 14:01:32,600 - INFO - 	Detector drift effects turned ON.
# 2020-02-25 14:01:32,601 - INFO - 	Detector latency effects turned ON.
# 2020-02-25 14:01:32,603 - INFO - Creating a new detector object for 1024 rows x 1024 columns.
# 2020-02-25 14:01:32,630 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2020-02-25 14:01:32,719 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 14:01:32,766 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2020-02-25 14:01:32,926 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_FLAT_8B.01.00.fits'
# 2020-02-25 14:01:33,082 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='SHORT'. An alternative is being used.
# 2020-02-25 14:01:33,130 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits'
# 2020-02-25 14:01:33,394 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2020-02-25 14:01:33,459 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-25 14:01:33,564 - INFO - Simulating 3 integrations.
# 2020-02-25 14:01:33,579 - WARNING - ***Input flux array contains 2 negative values.
# 2020-02-25 14:01:33,639 - INFO - Simulating 80 groups for integration 1.
# 2020-02-25 14:01:53,939 - INFO - Simulating 80 groups for integration 2.
# 2020-02-25 14:02:15,076 - INFO - Simulating 80 groups for integration 3.
# 2020-02-25 14:02:36,406 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2020-02-25 14:02:43,499 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits
# 2020-02-25 14:03:02,876 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-25 14:03:19,468 - INFO - Wrote detector image: 20200225_135051_mirisim/det_images/det_image_seq1_MIRIFULONG_34SHORTexp1.fits
# 2020-02-25 14:03:19,470 - INFO - MIRI Simulation finished. Results have been saved to: 20200225_135051_mirisim
#
# 2020-02-25 14:03:19,475 - INFO - MIRISim version: 2.2.0dev0
# 2020-02-25 14:03:19,476 - INFO - MIRI Simulation started.
# 2020-02-25 14:03:19,477 - INFO - Output will be saved to: 20200225_140319_mirisim
# 2020-02-25 14:03:19,478 - INFO - Storing configs in output directory.
# 2020-02-25 14:03:19,482 - INFO - Using $CDP_DIR for location of CDP files: //Users/ojones/Data/MIRI_testing
# 2020-02-25 14:03:19,483 - INFO -
# 2020-02-25 14:03:19,484 - INFO - 	*** Detector hard reset. NOTE: All latency and drift data will be erased.
# 2020-02-25 14:03:19,669 - INFO -
# 2020-02-25 14:03:19,670 - INFO - 	*** Detector hard reset. NOTE: All latency and drift data will be erased.
# 2020-02-25 14:03:19,741 - INFO - Setting up simulated Observation, with following settings:
# 2020-02-25 14:03:19,742 - INFO - Configuration Path: MRS_1MEDIUM
# 2020-02-25 14:03:19,743 - INFO - Primary optical path: MRS
# 2020-02-25 14:03:19,744 - INFO - MRS detector: BOTH
# 2020-02-25 14:03:19,745 - INFO - MRS band: MEDIUM
# 2020-02-25 14:03:19,746 - INFO - MRS detector readout mode: FAST
# 2020-02-25 14:03:19,747 - INFO - MRS detector # exposures: 1
# 2020-02-25 14:03:19,749 - INFO - MRS detector # integrations: 3
# 2020-02-25 14:03:19,750 - INFO - MRS detector # frames: 80
# 2020-02-25 14:03:19,751 - INFO - Parsing: Background
# 2020-02-25 14:03:19,752 - INFO - Initializing Background
# 2020-02-25 14:03:19,753 - INFO - Parsing: point_1
# 2020-02-25 14:03:19,755 - INFO - Initializing Point
# 2020-02-25 14:03:19,757 - INFO - Parsing: galaxy_1
# 2020-02-25 14:03:19,759 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,760 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,761 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,790 - INFO - Parsing: galaxy_2
# 2020-02-25 14:03:19,791 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,793 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,793 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,821 - INFO - Parsing: galaxy_3
# 2020-02-25 14:03:19,822 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,823 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,824 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,850 - INFO - Parsing: galaxy_4
# 2020-02-25 14:03:19,851 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,852 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,854 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,890 - INFO - Parsing: galaxy_5
# 2020-02-25 14:03:19,891 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,892 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,894 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,928 - INFO - Parsing: galaxy_6
# 2020-02-25 14:03:19,930 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,930 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,931 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,956 - INFO - Parsing: galaxy_7
# 2020-02-25 14:03:19,957 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,958 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19,959 - INFO - Initializing Galaxy
# 2020-02-25 14:03:19
- INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-25 14:05:29,760 - INFO - MRS light path simulation starting.
# 2020-02-25 14:05:29,760 - INFO - Simulating Instrument.
# 2020-02-25 14:05:29,780 - INFO - Simulating Detector.
# 2020-02-25 14:05:29,781 - INFO - Simulating Detector Mapping for channel ['1'] and band MEDIUM
# 2020-02-25 14:05:29,782 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:05:29,785 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-25 14:05:30,263 - INFO - Valid cache found.
# 2020-02-25 14:05:30,265 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:05:42,291 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:07:05,727 - INFO - Mapping completed
# 2020-02-25 14:07:05,728 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:07:06,422 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_FRINGE_07.02.05.fits'
# 2020-02-25 14:07:06,619 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-25 14:07:06,761 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 14:07:06,816 - INFO - Simulating Detector Mapping for channel ['2'] and band MEDIUM
# 2020-02-25 14:07:06,817 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:07:06,819 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-25 14:07:07,373 - INFO - Valid cache found.
# 2020-02-25 14:07:07,375 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:07:19,221 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:08:42,809 - INFO - Mapping completed
# 2020-02-25 14:08:42,810 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:08:43,310 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_FRINGE_07.02.05.fits'
# 2020-02-25 14:08:43,457 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-25 14:08:43,564 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 14:08:43,595 - INFO - MRS light path simulation finished.
# 2020-02-25 14:08:43,605 - INFO - Added 1 Cube to output list
# 2020-02-25 14:08:43,606 - INFO - Added 2 Cube to output list
# 2020-02-25 14:08:43,713 - INFO - Starting pySpecSimMiri
# 2020-02-25 14:08:43,724 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-25 14:08:43,725 - INFO - Instrument setup starting.
# 2020-02-25 14:08:43,725 - INFO - Detector setup starting.
# 2020-02-25 14:08:43,728 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-25 14:08:43,730 - INFO - MRS light path simulation starting.
# 2020-02-25 14:08:43,731 - INFO - Simulating Instrument.
# 2020-02-25 14:08:43,741 - INFO - Simulating Detector.
# 2020-02-25 14:08:43,742 - INFO - Simulating Detector Mapping for channel ['3'] and band MEDIUM
# 2020-02-25 14:08:43,743 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:08:43,744 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-25 14:08:44,232 - INFO - Valid cache found.
# 2020-02-25 14:08:44,234 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:08:56,605 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:10:22,672 - INFO - Mapping completed
# 2020-02-25 14:10:22,672 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:10:23,134 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits'
# 2020-02-25 14:10:23,327 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_07.03.00.fits'
# 2020-02-25 14:10:23,476 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 14:10:23,535 - INFO - Simulating Detector Mapping for channel ['4'] and band MEDIUM
# 2020-02-25 14:10:23,536 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:10:23,538 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2020-02-25 14
DISTORTION_8B.05.01.fits'
# 2020-02-25 14:17:37,090 - INFO - Valid cache found.
# 2020-02-25 14:17:37,093 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:17:50,568 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:19:12,296 - INFO - Mapping completed
# 2020-02-25 14:19:12,297 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:19:12,923 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_FRINGE_07.02.05.fits'
# 2020-02-25 14:19:13,117 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_PHOTOM_07.03.00.fits'
# 2020-02-25 14:19:13,256 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 14:19:13,310 - INFO - Simulating Detector Mapping for channel ['2'] and band LONG
# 2020-02-25 14:19:13,311 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:19:13,313 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_DISTORTION_8B.05.01.fits'
# 2020-02-25 14:19:13,795 - INFO - Valid cache found.
# 2020-02-25 14:19:13,798 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:19:26,606 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:20:53,134 - INFO - Mapping completed
# 2020-02-25 14:20:53,135 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:20:53,605 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_FRINGE_07.02.05.fits'
# 2020-02-25 14:20:53,748 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_PHOTOM_07.03.00.fits'
# 2020-02-25 14:20:53,848 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 14:20:53,877 - INFO - MRS light path simulation finished.
# 2020-02-25 14:20:53,888 - INFO - Added 1 Cube to output list
# 2020-02-25 14:20:53,889 - INFO - Added 2 Cube to output list
# 2020-02-25 14:20:53,987 - INFO - Starting pySpecSimMiri
# 2020-02-25 14:20:53,998 - INFO - Simulating setup file /Users/ojones/anaconda3/envs/miricle.test/lib/python3.6/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2020-02-25 14:20:53,999 - INFO - Instrument setup starting.
# 2020-02-25 14:20:54,001 - INFO - Detector setup starting.
# 2020-02-25 14:20:54,001 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2020-02-25 14:20:54,004 - INFO - MRS light path simulation starting.
# 2020-02-25 14:20:54,005 - INFO - Simulating Instrument.
# 2020-02-25 14:20:54,017 - INFO - Simulating Detector.
# 2020-02-25 14:20:54,018 - INFO - Simulating Detector Mapping for channel ['3'] and band LONG
# 2020-02-25 14:20:54,019 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:20:54,022 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_DISTORTION_8B.05.01.fits'
# 2020-02-25 14:20:54,619 - INFO - Valid cache found.
# 2020-02-25 14:20:54,622 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:21:07,119 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:22:35,323 - INFO - Mapping completed
# 2020-02-25 14:22:35,324 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:22:35,776 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_FRINGE_07.02.00.fits'
# 2020-02-25 14:22:35,981 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_PHOTOM_07.03.00.fits'
# 2020-02-25 14:22:36,126 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 14:22:36,185 - INFO - Simulating Detector Mapping for channel ['4'] and band LONG
# 2020-02-25 14:22:36,185 - INFO - Getting Coefficients and Substitute values
# 2020-02-25 14:22:36,187 - INFO - Reading 'DISTORTION' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_DISTORTION_8B.05.01.fits'
# 2020-02-25 14:22:36,618 - INFO - Valid cache found.
# 2020-02-25 14:22:36,620 - INFO - Starting Coordinate Transformation
# 2020-02-25 14:22:45,108 - INFO - Starting pixel projection with cache.
# 2020-02-25 14:23:43,750 - INFO - Mapping completed
# 2020-02-25 14:23:43,751 - INFO - Detector Intensity Array completed.
# 2020-02-25 14:23:44,085 - INFO - Reading 'FRINGE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_FRINGE_07.02.00.fits'
# 2020-02-25 14:23:44,221 - INFO - Reading 'PHOTOM' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_PHOTOM_07.03.00.fits'
# 2020-02-25 14:23:44,324 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 14:23:44,354 - INFO - MRS light path simulation finished.
# 2020-02-25 14:23:44,363 - INFO - Added 3 Cube to output list
# 2020-02-25 14:23:44,364 - INFO - Added 4 Cube to output list
# 2020-02-25 14:23:44,548 - INFO - Wrote illumination model: 20200225_141503_mirisim/illum_models/illum_model_seq1_MIRIFUSHORT_12LONG.fits
# 2020-02-25 14:23:44,602 - INFO - Wrote illumination model: 20200225_141503_mirisim/illum_models/illum_model_seq1_MIRIFULONG_34LONG.fits
# 2020-02-25 14:23:44,603 - INFO - Simulating integrated detector images for MRS exposures for pointing 1
# 2020-02-25 14:23:44,604 - INFO - Simulating MRS exposure 1
# 2020-02-25 14:23:44,609 - INFO - Running SCASim
# 2020-02-25 14:23:44,610 - INFO - Simulating  detector readout for MIRIFUSHORT from illumination data model of shape (1024, 1024).
# 2020-02-25 14:23:44,623 - INFO - Results will be returned in an exposure data model.
# 2020-02-25 14:23:44,639 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-25 14:23:44,640 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-25 14:23:44,641 - INFO -   Detector subarray mode is FULL.
# 2020-02-25 14:23:44,643 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-25 14:23:44,645 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2020-02-25 14:23:44,645 - INFO - Simulation control flags:
# 2020-02-25 14:23:44,646 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-25 14:23:44,647 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-25 14:23:44,648 - INFO - 	Read noise simulation turned ON.
# 2020-02-25 14:23:44,649 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-25 14:23:44,649 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-25 14:23:44,651 - INFO - 	Dark current simulation turned ON.
# 2020-02-25 14:23:44,651 - INFO - 	Flat-field simulation turned ON.
# 2020-02-25 14:23:44,652 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-25 14:23:44,652 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-25 14:23:44,654 - INFO - 	Detector drift effects turned ON.
# 2020-02-25 14:23:44,655 - INFO - 	Detector latency effects turned ON.
# 2020-02-25 14:23:44,659 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_MASK_07.02.01.fits'
# 2020-02-25 14:23:44,754 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_GAIN_04.00.00.fits'
# 2020-02-25 14:23:44,828 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits'
# 2020-02-25 14:23:45,176 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12LONG_FLAT_8B.01.00.fits'
# 2020-02-25 14:23:45,303 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFUSHORT with FAST mode with band='LONG'. An alternative is being used.
# 2020-02-25 14:23:45,339 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits'
# 2020-02-25 14:23:45,599 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_READNOISE_07.01.00.fits'
# 2020-02-25 14:23:45,676 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-25 14:23:45,787 - INFO - Simulating 3 integrations.
# 2020-02-25 14:23:45,794 - WARNING - ***Input flux array contains 1 negative values.
# 2020-02-25 14:23:45,954 - INFO - Simulating 80 groups for integration 1.
# 2020-02-25 14:24:05,648 - INFO - Simulating 80 groups for integration 2.
# 2020-02-25 14:24:26,630 - INFO - Simulating 80 groups for integration 3.
# 2020-02-25 14:24:47,536 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFUSHORT_FAST_12_DARK_06.01.00.fits
# 2020-02-25 14:24:52,072 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits
# 2020-02-25 14:25:08,991 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-25 14:25:24,874 - INFO - Wrote detector image: 20200225_141503_mirisim/det_images/det_image_seq1_MIRIFUSHORT_12LONGexp1.fits
# 2020-02-25 14:25:24,878 - INFO - Simulating MRS exposure 1
# 2020-02-25 14:25:24,882 - INFO - Running SCASim
# 2020-02-25 14:25:24,883 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2020-02-25 14:25:24,896 - INFO - Results will be returned in an exposure data model.
# 2020-02-25 14:25:24,917 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2020-02-25 14:25:24,918 - INFO -   with 3 integrations and ngroups=80 defined explicitly.
# 2020-02-25 14:25:24,918 - INFO -   Detector subarray mode is FULL.
# 2020-02-25 14:25:24,920 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2020-02-25 14:25:24,922 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2020-02-25 14:25:24,923 - INFO - Simulation control flags:
# 2020-02-25 14:25:24,924 - INFO - 	Quantum efficiency simulation turned OFF.
# 2020-02-25 14:25:24,925 - INFO - 	Poisson noise simulation turned ON.
# 2020-02-25 14:25:24,925 - INFO - 	Read noise simulation turned ON.
# 2020-02-25 14:25:24,926 - INFO - 	Reference pixels simulation turned ON.
# 2020-02-25 14:25:24,927 - INFO - 	Bad pixels simulation turned ON.
# 2020-02-25 14:25:24,928 - INFO - 	Dark current simulation turned ON.
# 2020-02-25 14:25:24,929 - INFO - 	Flat-field simulation turned ON.
# 2020-02-25 14:25:24,930 - INFO - 	Amplifier bias and gain turned ON.
# 2020-02-25 14:25:24,931 - INFO - 	Detector non-linearity effects turned ON.
# 2020-02-25 14:25:24,932 - INFO - 	Detector drift effects turned ON.
# 2020-02-25 14:25:24,932 - INFO - 	Detector latency effects turned ON.
# 2020-02-25 14:25:24,937 - INFO - Reading 'MASK' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2020-02-25 14:25:25,025 - INFO - Reading 'GAIN' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2020-02-25 14:25:25,092 - INFO - Reading DARK model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2020-02-25 14:25:25,270 - INFO - Reading 'PIXELFLAT' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_FLAT_8B.01.00.fits'
# 2020-02-25 14:25:25,397 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='LONG'. An alternative is being used.
# 2020-02-25 14:25:25,428 - INFO - Reading 'LINEARITY' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits'
# 2020-02-25 14:25:25,733 - INFO - Reading 'READNOISE' model from '//Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2020-02-25 14:25:25,829 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 80 groups and 3 ints.
# 2020-02-25 14:25:25,942 - INFO - Simulating 3 integrations.
# 2020-02-25 14:25:25,950 - WARNING - ***Input flux array contains 6822 negative values.
# 2020-02-25 14:25:26,081 - INFO - Simulating 80 groups for integration 1.
# 2020-02-25 14:25:48,023 - INFO - Simulating 80 groups for integration 2.
# 2020-02-25 14:26:09,797 - INFO - Simulating 80 groups for integration 3.
# 2020-02-25 14:26:31,351 - INFO - Adding the DARK calibration from //Users/ojones/Data/MIRI_testing/fitsCDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2020-02-25 14:26:37,291 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits
# 2020-02-25 14:26:55,331 - INFO - Exposure time 666.01s (duration 667.07s)
# 2020-02-25 14:27:11,373 - INFO - Wrote detector image: 20200225_141503_mirisim/det_images/det_image_seq1_MIRIFULONG_34LONGexp1.fits
# 2020-02-25 14:27:11,381 - INFO - MIRI Simulation finished. Results have been saved to: 20200225_141503_mirisim

# %% [markdown]
# ## Examine some of the results
#
# Outputs are in a date-labelled directory taking the form  <code>YYYYMMDD_hhmmss_mirisim</code>.  The name of the output directory is given in the last line of the MIRISim log above.  Because the output directory is date-labelled, we can quantify which was the most recent run of MIRISim, and find its output directory using <code>glob.glob</code>

# %% [markdown]
# ### The results of the MRS simulation for the 5-28 micron range are contained in three directories - one for each disperser

# %%
directory_list = sorted(glob.glob('*_*_mirisim'),key=os.path.getmtime)[-3:] # Takes the last three entry found

# %%
for num, outputdir in enumerate(directory_list):
    outputDirContents = os.listdir(outputdir)
    
    directories = [name for name in outputDirContents if os.path.isdir(os.path.join(outputdir,name))]
    files = [name for name in outputDirContents if not os.path.isdir(os.path.join(outputdir,name))]

    print('\nFor the {} the output directory is: {} '.format(sim_filenames[num], outputdir))
    print('The subdirectories in the {} directory are:\n{}'.format(outputdir,directories))
    print('The files in the output directory are:\n{}'.format(files))
# Out:
# For the MRS_short_SN1987A_simulation the output directory is: 20200225_140319_mirisim
# The subdirectories in the 20200225_140319_mirisim directory are:
# ['det_images', 'illum_models', 'skycubes']
# The files in the output directory are:
# ['mirisim.log', 'scene.ini', 'simulation.ini', 'simulator.ini']
#
# For the MRS_medium_SN1987A_simulation the output directory is: 20200225_141701_mirisim
# The subdirectories in the 20200225_141701_mirisim directory are:
# ['det_images', 'illum_models']
# The files in the output directory are:
# ['mirisim.log', 'scene.ini', 'simulation.ini', 'simulator.ini']
#
# For the MRS_long_SN1987A_simulation the output directory is: 20200225_141503_mirisim
# The subdirectories in the 20200225_141503_mirisim directory are:
# ['det_images', 'illum_models', 'skycubes']
# The files in the output directory are:
# ['mirisim.log', 'scene.ini', 'simulation.ini', 'simulator.ini']

# %% [markdown]
# The files contain the log which was also output to the terminal (<code>mirisim.log</code>) and the .ini files used to create the simulation. These versions of the .ini files can be used to re-create the run of the simulation.
#
# The directories contain various outputs of MIRISim:
#
# * **<code> skycubes </code>** houses a 3D representation of the input scene to the MRS simulation (skycubes are not generated for imager or LRS simulations). This cube has not been processed by MIRISim, it is simply a gridded (spatially and spectrally) version of the input scene.
# * **<code> illum_models </code>** houses FITS images of the illuminations sent to the detector (sent to SCAsim - the simulator of the Sensor Chip Assembly).  This should have the same format as the detector image, but without all of the detector effects and noise. There are FITS files produced for each exposure and dither position
# * **<code> det_images </code>** houses FITS images of the final outputs of MIRISim. These detector images have all of the detector effects and noise incorporated. The number of detector images should be the same as the number of illumination models.
#
# The headers of the detector images are formatted for ingest into the JWST pipeline.

# %% [markdown]
# ### Viewing a slice of the skycube
#
# Below, we show an image of the central channel of one of the skycubes generated by MIRISim.
#
# NOTE: The symmetric ring generated in the scene may appear as an ellipse in the sky cube slice. This is due to the aspect ratio and automatic axis functionality in matplotlib.

# %%
show_outputs(directory_list[2],'skycubes')

# %% [markdown]
# ### Viewing an averaged spectrum over the full MRS FOV for each disperser and channel of the input scene to the MRS simulation
#
# For the full MRS spectral range a total of **12** **<code>skycubes</code>** are generated by MIRISim- four per disperser. NOTE: These cubes have not been processed by MIRISim.
# Below, we show an average spectum for the input scene across the MRS FOV for each of the 12 **<code>skycubes</code>**. The wavelength ranges of each skycube is also printed.
#
# NOTE: The fluxes are not normalised between each indivisual plot.

# %%
show_skycubes_spec(directory_list)

# %% [markdown]
# ## Viewing the final detector image
#
# The detector images are the final output of MIRISim, and have data structures and formatting consistent with what will come from MIRI itself. The data format is JWST pipeline ready.  Below an example image of the last frame of the last integration is shown. The units are <code>DN</code>.

# %%
### Loop for all simulations  - SML for 1/2 and 3/4 
for outputdir in directory_list:
    filenames_det_images = glob.glob('{}/{}/*.fits'.format(outputdir,'det_images')) # Get skycube file
    
    for det_images_file in filenames_det_images:
        
        hdulist = fits.open(det_images_file) # Open file 

        hdu_index = 1
        if len(hdulist[hdu_index].data.shape) > 2:
            integ,frames,nx,ny = hdulist[hdu_index].data.shape
            image = hdulist[hdu_index].data[integ-1,frames-1,:,:]
        else:
            image = hdulist[hdu_index].data

        plt.imshow(image, origin = 'lower',cmap = cm.viridis,interpolation='nearest')
        plt.title('{}'.format(det_images_file.split('/')[-1]))
        plt.xlabel('Along Slice Direction')
        plt.ylabel('Wavelength Direction')
        plt.show()
        plt.close()

# %% [markdown]
# ## The outputs of MIRISim can now be run through the JWST pipeline see:
# ###  https://jwst-docs.stsci.edu/jwst-data-reduction-pipeline and https://jwst-pipeline.readthedocs.io/en/stable/
